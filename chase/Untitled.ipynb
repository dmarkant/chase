# %%
from chase.initial_distribution import laplace_initial_distribution

# %%
plt.plot(range(-5, 6),
         np.array(laplace_initial_distribution(11, {'theta': 5}))[0])
plt.plot(range(-10, 11),
         np.array(laplace_initial_distribution(21, {'theta': 10}))[0])

# %%
plt.plot(np.array(laplace_initial_distribution(21, {'theta': 10}))[0])
