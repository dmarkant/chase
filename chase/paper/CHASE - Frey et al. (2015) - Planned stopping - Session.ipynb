# %%
from chase.base import *
from chase.utils import *
from chase.fit import *
from mypy.explib.frey2014 import frey2014
pd.set_option('display.max_colwidth', 100)

# %%
arr = []
for sid in frey2014.subjects():
    print sid
    data = frey2014.subject_fitdata(sid)
    for d in data:
        arr.append([sid, d['gid'], d['group'], d['data'][0,0], d['data'][0,1]])
        
    df = pd.DataFrame(arr, columns=['subject', 'problem', 'group', 'choice', 'samplesize'])
df.to_csv('frey_data.csv')

# %%
df = frey2014.load_data()

# %%
df.to_csv('/Users/markant/Dropbox/SequentialSamplingDFE/frey_trial_data.csv')

# %%
data = pd.read_csv('data/frey_data.csv', index_col=0)
problems = {gid: frey2014.get_options(gid) for gid in data.problem.unique()}
arr = []
for i, row in data.iterrows():
    arr.append(row['problem'].split('G')[0])
data['session'] = arr
data.head(10)
# Out:
#    subject problem  group  choice  samplesize session
# 0        1    S1G1      0       0          12      S1
# 1        1    S2G1      0       1          10      S2
# 2        1    S3G1      0       0          10      S3
# 3        1    S4G1      0       0          10      S4
# 4        1    S5G1      0       0          10      S5
# 5        1    S6G1      0       1          10      S6
# 6        1    S7G1      0       0          10      S7
# 7        1    S8G1      0       0          12      S8
# 8        1    S9G1      0       0          10      S9
# 9        1   S10G1      0       0          10     S10

# %% [markdown]
# # Fit individual subjects

# %%
# a list of possible free parameters and their ranges
# and starting point (optional)
PARS = {'theta': [1, 50],
        'p_stay': [0, 1, .5],
        'tau': [0, 1, .5],
        'prelec_gamma': [0, 5, 1.],
        'prelec_elevation': [0, 5, 1.],
        'pow_gain': [0., 20., 1.],
        'w_loss': [0., np.inf, 1.],
        'mu': [0., np.inf, 20.],
        'sc': [0., np.inf, 1.],
        'p_stop': [0, 1, .5]}

# parameters that are set to fixed values 
FIXED = {'c': 0.5,
         'theta': 30}

N_ITER = 3
OUTDIR = 'chase_fitresults_frey_session'

# a list of different parameter combinations that will
# be fit
PARSETS_GEOM = [#['p_stop', 'p_stay', 'tau'],
                #['p_stop', 'p_stay', 'tau', 'prelec_gamma'],
                ['p_stop', 'p_stay', 'tau', 'prelec_gamma', 'prelec_elevation'],
                #['p_stop', 'p_stay', 'tau', 'pow_gain'],
                ['p_stop', 'p_stay', 'tau', 'pow_gain', 'w_loss'],
               ]

PARSETS_NORMAL = [#['mu', 'sc', 'p_stay', 'tau'],
                  #['mu', 'sc', 'p_stay', 'tau', 'prelec_gamma'],
                  ['mu', 'sc', 'p_stay', 'tau', 'prelec_gamma', 'prelec_elevation'],
                  #['mu', 'sc', 'p_stay', 'tau', 'pow_gain'],
                  ['mu', 'sc', 'p_stay', 'tau', 'pow_gain', 'w_loss'],
                  ]

# %% [markdown]
# ### Geometric

# %%
for sid in data.session.unique():

    SIM_ID = 'frey_individual_planned_geom_session=%s' % sid

    for parset in PARSETS_GEOM:

        fitting = {p: PARS[p] for p in parset}

        # initialize the model
        m = CHASEAlternateStoppingModel(drift='cpt',
                                        startdist='laplace',
                                        stoprule='geometric',
                                        problems=problems)

        # fit
        results = fit_mlh(m, problems, data[data.session==sid], 
                          SIM_ID, FIXED, fitting, niter=N_ITER, outdir=OUTDIR,
                          method='Powell')

        print results.sort('nllh').head(1)
# Out:
# frey_individual_planned_geom_session=S1(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                    0
# success                   True
# nllh                  1390.575
# k                            5
# N                          280
# bic                   2809.323
# theta                       30
# p_stay               0.6658153
# p_stop              0.03567396
# prelec_elevation      1.705123
# prelec_gamma          1.092343
# tau                   0.490592
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                    1
# success                   True
# nllh                  1390.575
# k                            5
# N                          280
# bic                   2809.323
# theta                       30
# p_stay               0.6658153
# p_stop              0.03567396
# prelec_elevation      1.705123
# prelec_gamma          1.092343
# tau                   0.490592
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                    2
# success                   True
# nllh                  1390.575
# k                            5
# N                          280
# bic                   2809.323
# theta                       30
# p_stay               0.6658153
# p_stop              0.03567396
# prelec_elevation      1.705123
# prelec_gamma          1.092343
# tau                   0.490592
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1390.574594  5  280  2809.323136     30  0.665815
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.035674          1.705123      1.092343  0.490592
# frey_individual_planned_geom_session=S1(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           1392.167
# k                     5
# N                   280
# bic            2812.508
# theta                30
# p_stay        0.6417043
# p_stop       0.03567396
# pow_gain      0.6141609
# tau          0.01940005
# w_loss         6.175858
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           1392.167
# k                     5
# N                   280
# bic            2812.508
# theta                30
# p_stay        0.6417043
# p_stop       0.03567396
# pow_gain      0.6141609
# tau          0.01940005
# w_loss         6.175858
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           1392.167
# k                     5
# N                   280
# bic            2812.508
# theta                30
# p_stay        0.6417043
# p_stop       0.03567396
# pow_gain      0.6141609
# tau          0.01940005
# w_loss         6.175858
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1392.166951  5  280  2812.507851     30  0.641704
#
#      p_stop  pow_gain     tau    w_loss
# 0  0.035674  0.614161  0.0194  6.175858
# frey_individual_planned_geom_session=S2(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1396.678
# k                              5
# N                            279
# bic                     2821.512
# theta                         30
# p_stay                 0.2307423
# p_stop                 0.0350967
# prelec_elevation        1.249776
# prelec_gamma           0.9131727
# tau                 6.309973e-05
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1396.678
# k                              5
# N                            279
# bic                     2821.512
# theta                         30
# p_stay                 0.2307423
# p_stop                 0.0350967
# prelec_elevation        1.249776
# prelec_gamma           0.9131727
# tau                 6.309973e-05
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1396.678
# k                              5
# N                            279
# bic                     2821.512
# theta                         30
# p_stay                 0.2307423
# p_stop                 0.0350967
# prelec_elevation        1.249776
# prelec_gamma           0.9131727
# tau                 6.309973e-05
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1396.678137  5  279  2821.512333     30  0.230742
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.035097          1.249776      0.913173  0.000063
# frey_individual_planned_geom_session=S2(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration            0
# success           True
# nllh          1395.938
# k                    5
# N                  279
# bic           2820.031
# theta               30
# p_stay       0.3255826
# p_stop       0.0350967
# pow_gain     0.6415591
# tau          0.3697293
# w_loss        6.175858
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration            1
# success           True
# nllh          1395.938
# k                    5
# N                  279
# bic           2820.031
# theta               30
# p_stay       0.3255826
# p_stop       0.0350967
# pow_gain     0.6415591
# tau          0.3697293
# w_loss        6.175858
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration            2
# success           True
# nllh          1395.938
# k                    5
# N                  279
# bic           2820.031
# theta               30
# p_stay       0.3255826
# p_stop       0.0350967
# pow_gain     0.6415591
# tau          0.3697293
# w_loss        6.175858
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1395.937502  5  279  2820.031063     30  0.325583
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.035097  0.641559  0.369729  6.175858
# frey_individual_planned_geom_session=S3(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                     1378.78
# k                              5
# N                            280
# bic                     2785.735
# theta                         30
# p_stay              4.776541e-05
# p_stop                0.03704013
# prelec_elevation        1.352235
# prelec_gamma           0.9820685
# tau                    0.7549077
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                     1378.78
# k                              5
# N                            280
# bic                     2785.735
# theta                         30
# p_stay              4.776541e-05
# p_stop                0.03704013
# prelec_elevation        1.352235
# prelec_gamma           0.9820685
# tau                    0.7549077
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                     1378.78
# k                              5
# N                            280
# bic                     2785.735
# theta                         30
# p_stay              4.776541e-05
# p_stop                0.03704013
# prelec_elevation        1.352235
# prelec_gamma           0.9820685
# tau                    0.7549077
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1378.780295  5  280  2785.734538     30  0.000048
#
#     p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.03704          1.352235      0.982069  0.754908
# frey_individual_planned_geom_session=S3(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1379.259
# k                       5
# N                     280
# bic              2786.692
# theta                  30
# p_stay       6.352546e-05
# p_stop         0.03704013
# pow_gain        0.6543677
# tau             0.7187608
# w_loss           2.753289
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1379.259
# k                       5
# N                     280
# bic              2786.692
# theta                  30
# p_stay       6.352546e-05
# p_stop         0.03704013
# pow_gain        0.6543677
# tau             0.7187608
# w_loss           2.753289
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1379.259
# k                       5
# N                     280
# bic              2786.692
# theta                  30
# p_stay       6.352546e-05
# p_stop         0.03704013
# pow_gain        0.6543677
# tau             0.7187608
# w_loss           2.753289
# Name: 2, dtype: object
#    iteration success         nllh  k    N         bic  theta    p_stay  \
# 0          0    True  1379.258866  5  280  2786.69168     30  0.000064
#
#     p_stop  pow_gain       tau    w_loss
# 0  0.03704  0.654368  0.718761  2.753289
# frey_individual_planned_geom_session=S4(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1405.786
# k                              5
# N                            280
# bic                     2839.746
# theta                         30
# p_stay                 0.6250769
# p_stop                0.03449187
# prelec_elevation        1.306256
# prelec_gamma            1.066631
# tau                 1.444166e-05
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1405.786
# k                              5
# N                            280
# bic                     2839.746
# theta                         30
# p_stay                 0.6250769
# p_stop                0.03449187
# prelec_elevation        1.306256
# prelec_gamma            1.066631
# tau                 1.444166e-05
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1405.786
# k                              5
# N                            280
# bic                     2839.746
# theta                         30
# p_stay                 0.6250769
# p_stop                0.03449187
# prelec_elevation        1.306256
# prelec_gamma            1.066631
# tau                 1.444166e-05
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1405.786206  5  280  2839.746361     30  0.625077
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.034492          1.306256      1.066631  0.000014
# frey_individual_planned_geom_session=S4(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1406.644
# k                       5
# N                     280
# bic              2841.462
# theta                  30
# p_stay           0.282351
# p_stop         0.03449187
# pow_gain        0.7905979
# tau          1.909919e-05
# w_loss           6.175858
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1406.644
# k                       5
# N                     280
# bic              2841.462
# theta                  30
# p_stay           0.282351
# p_stop         0.03449187
# pow_gain        0.7905979
# tau          1.909919e-05
# w_loss           6.175858
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1406.644
# k                       5
# N                     280
# bic              2841.462
# theta                  30
# p_stay           0.282351
# p_stop         0.03449187
# pow_gain        0.7905979
# tau          1.909919e-05
# w_loss           6.175858
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1406.644075  5  280  2841.462098     30  0.282351
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.034492  0.790598  0.000019  6.175858
# frey_individual_planned_geom_session=S5(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1380.902
# k                              5
# N                            280
# bic                     2789.977
# theta                         30
# p_stay                 0.2460402
# p_stop                0.03735496
# prelec_elevation        1.365525
# prelec_gamma            0.989427
# tau                 4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1380.902
# k                              5
# N                            280
# bic                     2789.977
# theta                         30
# p_stay                 0.2460402
# p_stop                0.03735496
# prelec_elevation        1.365525
# prelec_gamma            0.989427
# tau                 4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1380.902
# k                              5
# N                            280
# bic                     2789.977
# theta                         30
# p_stay                 0.2460402
# p_stop                0.03735496
# prelec_elevation        1.365525
# prelec_gamma            0.989427
# tau                 4.842124e-06
# Name: 2, dtype: object
#    iteration success         nllh  k    N         bic  theta   p_stay  \
# 0          0    True  1380.901601  5  280  2789.97715     30  0.24604
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.037355          1.365525      0.989427  0.000005
# frey_individual_planned_geom_session=S5(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh              1381.05
# k                       5
# N                     280
# bic              2790.274
# theta                  30
# p_stay          0.3031155
# p_stop         0.03735496
# pow_gain        0.7018177
# tau          4.842124e-06
# w_loss           7.143566
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh              1381.05
# k                       5
# N                     280
# bic              2790.274
# theta                  30
# p_stay          0.3031155
# p_stop         0.03735496
# pow_gain        0.7018177
# tau          4.842124e-06
# w_loss           7.143566
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh              1381.05
# k                       5
# N                     280
# bic              2790.274
# theta                  30
# p_stay          0.3031155
# p_stop         0.03735496
# pow_gain        0.7018177
# tau          4.842124e-06
# w_loss           7.143566
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1381.050231  5  280  2790.274409     30  0.303115
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.037355  0.701818  0.000005  7.143566
# frey_individual_planned_geom_session=S6(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                    0
# success                   True
# nllh                  1362.364
# k                            5
# N                          280
# bic                   2752.903
# theta                       30
# p_stay               0.3251335
# p_stop              0.03905397
# prelec_elevation      1.565784
# prelec_gamma         0.9963417
# tau                 0.03669934
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                    1
# success                   True
# nllh                  1362.364
# k                            5
# N                          280
# bic                   2752.903
# theta                       30
# p_stay               0.3251335
# p_stop              0.03905397
# prelec_elevation      1.565784
# prelec_gamma         0.9963417
# tau                 0.03669934
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                    2
# success                   True
# nllh                  1362.364
# k                            5
# N                          280
# bic                   2752.903
# theta                       30
# p_stay               0.3251335
# p_stop              0.03905397
# prelec_elevation      1.565784
# prelec_gamma         0.9963417
# tau                 0.03669934
# Name: 2, dtype: object
#    iteration success         nllh  k    N         bic  theta    p_stay  \
# 0          0    True  1362.364406  5  280  2752.90276     30  0.325133
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.039054          1.565784      0.996342  0.036699
# frey_individual_planned_geom_session=S6(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           1362.305
# k                     5
# N                   280
# bic            2752.785
# theta                30
# p_stay        0.3152048
# p_stop       0.03905397
# pow_gain      0.5768525
# tau          0.01331309
# w_loss         6.150235
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           1362.305
# k                     5
# N                   280
# bic            2752.785
# theta                30
# p_stay        0.3152048
# p_stop       0.03905397
# pow_gain      0.5768525
# tau          0.01331309
# w_loss         6.150235
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           1362.305
# k                     5
# N                   280
# bic            2752.785
# theta                30
# p_stay        0.3152048
# p_stop       0.03905397
# pow_gain      0.5768525
# tau          0.01331309
# w_loss         6.150235
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1362.305459  5  280  2752.784866     30  0.315205
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.039054  0.576852  0.013313  6.150235
# frey_individual_planned_geom_session=S7(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1400.376
# k                              5
# N                            280
# bic                     2828.925
# theta                         30
# p_stay                 0.3226523
# p_stop                0.03448337
# prelec_elevation        1.350774
# prelec_gamma            1.070528
# tau                 4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1400.376
# k                              5
# N                            280
# bic                     2828.925
# theta                         30
# p_stay                 0.3226523
# p_stop                0.03448337
# prelec_elevation        1.350774
# prelec_gamma            1.070528
# tau                 4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1400.376
# k                              5
# N                            280
# bic                     2828.925
# theta                         30
# p_stay                 0.3226523
# p_stop                0.03448337
# prelec_elevation        1.350774
# prelec_gamma            1.070528
# tau                 4.842124e-06
# Name: 2, dtype: object
#    iteration success        nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1400.37552  5  280  2828.924987     30  0.322652
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.034483          1.350774      1.070528  0.000005
# frey_individual_planned_geom_session=S7(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1402.385
# k                       5
# N                     280
# bic              2832.945
# theta                  30
# p_stay          0.2480704
# p_stop         0.03448337
# pow_gain        0.7205672
# tau          4.842124e-06
# w_loss           4.669488
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1402.385
# k                       5
# N                     280
# bic              2832.945
# theta                  30
# p_stay          0.2480704
# p_stop         0.03448337
# pow_gain        0.7205672
# tau          4.842124e-06
# w_loss           4.669488
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1402.385
# k                       5
# N                     280
# bic              2832.945
# theta                  30
# p_stay          0.2480704
# p_stop         0.03448337
# pow_gain        0.7205672
# tau          4.842124e-06
# w_loss           4.669488
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta   p_stay  \
# 0          0    True  1402.385462  5  280  2832.944872     30  0.24807
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.034483  0.720567  0.000005  4.669488
# frey_individual_planned_geom_session=S8(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1355.683
# k                              5
# N                            278
# bic                     2739.504
# theta                         30
# p_stay                0.01443603
# p_stop                0.03726541
# prelec_elevation        1.261258
# prelec_gamma            1.171882
# tau                 6.571082e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1355.683
# k                              5
# N                            278
# bic                     2739.504
# theta                         30
# p_stay                0.01443603
# p_stop                0.03726541
# prelec_elevation        1.261258
# prelec_gamma            1.171882
# tau                 6.571082e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1355.683
# k                              5
# N                            278
# bic                     2739.504
# theta                         30
# p_stay                0.01443603
# p_stop                0.03726541
# prelec_elevation        1.261258
# prelec_gamma            1.171882
# tau                 6.571082e-07
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1355.682983  5  278  2739.504072     30  0.014436
#
#      p_stop  prelec_elevation  prelec_gamma           tau
# 0  0.037265          1.261258      1.171882  6.571082e-07
# frey_individual_planned_geom_session=S8(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1362.577
# k                       5
# N                     278
# bic              2753.291
# theta                  30
# p_stay       2.432826e-06
# p_stop         0.03727138
# pow_gain        0.7854993
# tau          8.467802e-05
# w_loss           5.506578
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1362.577
# k                       5
# N                     278
# bic              2753.291
# theta                  30
# p_stay       2.432826e-06
# p_stop         0.03727138
# pow_gain        0.7854993
# tau          8.467802e-05
# w_loss           5.506578
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1362.577
# k                       5
# N                     278
# bic              2753.291
# theta                  30
# p_stay       2.432826e-06
# p_stop         0.03727138
# pow_gain        0.7854993
# tau          8.467802e-05
# w_loss           5.506578
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1362.576598  5  278  2753.291302     30  0.000002
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.037271  0.785499  0.000085  5.506578
# frey_individual_planned_geom_session=S9(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1360.081
# k                              5
# N                            280
# bic                     2748.336
# theta                         30
# p_stay              3.028506e-07
# p_stop                0.04020042
# prelec_elevation        1.174489
# prelec_gamma            1.005299
# tau                    0.3223187
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1360.081
# k                              5
# N                            280
# bic                     2748.336
# theta                         30
# p_stay              3.028506e-07
# p_stop                0.04020042
# prelec_elevation        1.174489
# prelec_gamma            1.005299
# tau                    0.3223187
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1360.081
# k                              5
# N                            280
# bic                     2748.336
# theta                         30
# p_stay              3.028506e-07
# p_stop                0.04020042
# prelec_elevation        1.174489
# prelec_gamma            1.005299
# tau                    0.3223187
# Name: 2, dtype: object
#    iteration success         nllh  k    N         bic  theta        p_stay  \
# 0          0    True  1360.081181  5  280  2748.33631     30  3.028506e-07
#
#    p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.0402          1.174489      1.005299  0.322319
# frey_individual_planned_geom_session=S9(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1359.823
# k                       5
# N                     280
# bic              2747.819
# theta                  30
# p_stay       2.456499e-06
# p_stop         0.04020042
# pow_gain         0.816781
# tau             0.3530325
# w_loss           5.622371
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1359.823
# k                       5
# N                     280
# bic              2747.819
# theta                  30
# p_stay       2.456499e-06
# p_stop         0.04020042
# pow_gain         0.816781
# tau             0.3530325
# w_loss           5.622371
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1359.823
# k                       5
# N                     280
# bic              2747.819
# theta                  30
# p_stay       2.456499e-06
# p_stop         0.04020042
# pow_gain         0.816781
# tau             0.3530325
# w_loss           5.622371
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1359.822675  5  280  2747.819298     30  0.000002
#
#    p_stop  pow_gain       tau    w_loss
# 0  0.0402  0.816781  0.353032  5.622371
# frey_individual_planned_geom_session=S10(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1395.562
# k                              5
# N                            279
# bic                      2819.28
# theta                         30
# p_stay                 0.8396066
# p_stop                0.03457738
# prelec_elevation         2.26019
# prelec_gamma            1.070629
# tau                 0.0006833368
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1395.562
# k                              5
# N                            279
# bic                      2819.28
# theta                         30
# p_stay                 0.8396066
# p_stop                0.03457738
# prelec_elevation         2.26019
# prelec_gamma            1.070629
# tau                 0.0006833368
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1395.562
# k                              5
# N                            279
# bic                      2819.28
# theta                         30
# p_stay                 0.8396066
# p_stop                0.03457738
# prelec_elevation         2.26019
# prelec_gamma            1.070629
# tau                 0.0006833368
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1395.561727  5  279  2819.279514     30  0.839607
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.034577           2.26019      1.070629  0.000683
# frey_individual_planned_geom_session=S10(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           1393.919
# k                     5
# N                   279
# bic            2815.994
# theta                30
# p_stay        0.1665186
# p_stop       0.03457678
# pow_gain      0.4825058
# tau           0.2573587
# w_loss         5.184677
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           1393.919
# k                     5
# N                   279
# bic            2815.994
# theta                30
# p_stay        0.1665186
# p_stop       0.03457678
# pow_gain      0.4825058
# tau           0.2573587
# w_loss         5.184677
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           1393.919
# k                     5
# N                   279
# bic            2815.994
# theta                30
# p_stay        0.1665186
# p_stop       0.03457678
# pow_gain      0.4825058
# tau           0.2573587
# w_loss         5.184677
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1393.918909  5  279  2815.993876     30  0.166519
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.034577  0.482506  0.257359  5.184677
# frey_individual_planned_geom_session=S11(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                    0
# success                   True
# nllh                  1377.802
# k                            5
# N                          280
# bic                   2783.778
# theta                       30
# p_stay              0.04120713
# p_stop               0.0370745
# prelec_elevation       1.23179
# prelec_gamma          1.089048
# tau                  0.4793682
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                    1
# success                   True
# nllh                  1377.802
# k                            5
# N                          280
# bic                   2783.778
# theta                       30
# p_stay              0.04120713
# p_stop               0.0370745
# prelec_elevation       1.23179
# prelec_gamma          1.089048
# tau                  0.4793682
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                    2
# success                   True
# nllh                  1377.802
# k                            5
# N                          280
# bic                   2783.778
# theta                       30
# p_stay              0.04120713
# p_stop               0.0370745
# prelec_elevation       1.23179
# prelec_gamma          1.089048
# tau                  0.4793682
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1377.802137  5  280  2783.778222     30  0.041207
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.037074           1.23179      1.089048  0.479368
# frey_individual_planned_geom_session=S11(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration              0
# success             True
# nllh            1379.332
# k                      5
# N                    280
# bic             2786.838
# theta                 30
# p_stay       0.008239051
# p_stop         0.0370745
# pow_gain       0.7659218
# tau            0.3490498
# w_loss          5.830927
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration              1
# success             True
# nllh            1379.332
# k                      5
# N                    280
# bic             2786.838
# theta                 30
# p_stay       0.008239051
# p_stop         0.0370745
# pow_gain       0.7659218
# tau            0.3490498
# w_loss          5.830927
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration              2
# success             True
# nllh            1379.332
# k                      5
# N                    280
# bic             2786.838
# theta                 30
# p_stay       0.008239051
# p_stop         0.0370745
# pow_gain       0.7659218
# tau            0.3490498
# w_loss          5.830927
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1379.331824  5  280  2786.837595     30  0.008239
#
#      p_stop  pow_gain      tau    w_loss
# 0  0.037074  0.765922  0.34905  5.830927
# frey_individual_planned_geom_session=S12(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                   0
# success                  True
# nllh                 1391.504
# k                           5
# N                         279
# bic                  2811.163
# theta                      30
# p_stay              0.8420571
# p_stop              0.0356101
# prelec_elevation      1.83619
# prelec_gamma         1.042163
# tau                 0.5299492
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                   1
# success                  True
# nllh                 1391.504
# k                           5
# N                         279
# bic                  2811.163
# theta                      30
# p_stay              0.8420571
# p_stop              0.0356101
# prelec_elevation      1.83619
# prelec_gamma         1.042163
# tau                 0.5299492
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                   2
# success                  True
# nllh                 1391.504
# k                           5
# N                         279
# bic                  2811.163
# theta                      30
# p_stay              0.8420571
# p_stop              0.0356101
# prelec_elevation      1.83619
# prelec_gamma         1.042163
# tau                 0.5299492
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1391.503665  5  279  2811.163389     30  0.842057
#
#     p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.03561           1.83619      1.042163  0.529949
# frey_individual_planned_geom_session=S12(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1392.898
# k                       5
# N                     279
# bic              2813.951
# theta                  30
# p_stay          0.8577712
# p_stop          0.0356101
# pow_gain        0.5859529
# tau          5.204996e-05
# w_loss           6.896946
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1392.898
# k                       5
# N                     279
# bic              2813.951
# theta                  30
# p_stay          0.8577712
# p_stop          0.0356101
# pow_gain        0.5859529
# tau          5.204996e-05
# w_loss           6.896946
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1392.898
# k                       5
# N                     279
# bic              2813.951
# theta                  30
# p_stay          0.8577712
# p_stop          0.0356101
# pow_gain        0.5859529
# tau          5.204996e-05
# w_loss           6.896946
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1392.897604  5  279  2813.951267     30  0.857771
#
#     p_stop  pow_gain       tau    w_loss
# 0  0.03561  0.585953  0.000052  6.896946
# frey_individual_planned_geom_session=S13(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1368.314
# k                              5
# N                            280
# bic                     2764.802
# theta                         30
# p_stay              1.106046e-05
# p_stop                0.03757933
# prelec_elevation        1.425532
# prelec_gamma           0.9640187
# tau                 4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1368.314
# k                              5
# N                            280
# bic                     2764.802
# theta                         30
# p_stay              1.106046e-05
# p_stop                0.03757933
# prelec_elevation        1.425532
# prelec_gamma           0.9640187
# tau                 4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1368.314
# k                              5
# N                            280
# bic                     2764.802
# theta                         30
# p_stay              1.106046e-05
# p_stop                0.03757933
# prelec_elevation        1.425532
# prelec_gamma           0.9640187
# tau                 4.842124e-06
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1368.314251  5  280  2764.802449     30  0.000011
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.037579          1.425532      0.964019  0.000005
# frey_individual_planned_geom_session=S13(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1368.433
# k                       5
# N                     280
# bic              2765.039
# theta                  30
# p_stay       4.763831e-06
# p_stop         0.03757933
# pow_gain        0.5841528
# tau          4.842124e-06
# w_loss           2.786475
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1368.433
# k                       5
# N                     280
# bic              2765.039
# theta                  30
# p_stay       4.763831e-06
# p_stop         0.03757933
# pow_gain        0.5841528
# tau          4.842124e-06
# w_loss           2.786475
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1368.433
# k                       5
# N                     280
# bic              2765.039
# theta                  30
# p_stay       4.763831e-06
# p_stop         0.03757933
# pow_gain        0.5841528
# tau          4.842124e-06
# w_loss           2.786475
# Name: 2, dtype: object
#    iteration success        nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1368.43273  5  280  2765.039408     30  0.000005
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.037579  0.584153  0.000005  2.786475
# frey_individual_planned_geom_session=S14(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1373.234
# k                              5
# N                            280
# bic                     2774.642
# theta                         30
# p_stay              1.444986e-08
# p_stop                0.03649636
# prelec_elevation        1.734781
# prelec_gamma           0.6822636
# tau                 1.719895e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1373.234
# k                              5
# N                            280
# bic                     2774.642
# theta                         30
# p_stay              1.444986e-08
# p_stop                0.03649636
# prelec_elevation        1.734781
# prelec_gamma           0.6822636
# tau                 1.719895e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1373.234
# k                              5
# N                            280
# bic                     2774.642
# theta                         30
# p_stay              1.444986e-08
# p_stop                0.03649636
# prelec_elevation        1.734781
# prelec_gamma           0.6822636
# tau                 1.719895e-07
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        p_stay  \
# 0          0    True  1373.234193  5  280  2774.642335     30  1.444986e-08
#
#      p_stop  prelec_elevation  prelec_gamma           tau
# 0  0.036496          1.734781      0.682264  1.719895e-07
# frey_individual_planned_geom_session=S14(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1373.963
# k                       5
# N                     280
# bic              2776.099
# theta                  30
# p_stay          0.1649075
# p_stop          0.0364892
# pow_gain        0.5897084
# tau          6.874869e-05
# w_loss           3.965558
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1373.963
# k                       5
# N                     280
# bic              2776.099
# theta                  30
# p_stay          0.1649075
# p_stop          0.0364892
# pow_gain        0.5897084
# tau          6.874869e-05
# w_loss           3.965558
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1373.963
# k                       5
# N                     280
# bic              2776.099
# theta                  30
# p_stay          0.1649075
# p_stop          0.0364892
# pow_gain        0.5897084
# tau          6.874869e-05
# w_loss           3.965558
# Name: 2, dtype: object
#    iteration success        nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1373.96274  5  280  2776.099428     30  0.164908
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.036489  0.589708  0.000069  3.965558
# frey_individual_planned_geom_session=S15(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1369.222
# k                              5
# N                            280
# bic                     2766.618
# theta                         30
# p_stay                   0.84455
# p_stop                  0.038631
# prelec_elevation        3.183327
# prelec_gamma            0.901373
# tau                 4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1369.222
# k                              5
# N                            280
# bic                     2766.618
# theta                         30
# p_stay                   0.84455
# p_stop                  0.038631
# prelec_elevation        3.183327
# prelec_gamma            0.901373
# tau                 4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1369.222
# k                              5
# N                            280
# bic                     2766.618
# theta                         30
# p_stay                   0.84455
# p_stop                  0.038631
# prelec_elevation        3.183327
# prelec_gamma            0.901373
# tau                 4.842124e-06
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta   p_stay  \
# 0          0    True  1369.222154  5  280  2766.618255     30  0.84455
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.038631          3.183327      0.901373  0.000005
# frey_individual_planned_geom_session=S15(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1370.058
# k                       5
# N                     280
# bic               2768.29
# theta                  30
# p_stay          0.6322508
# p_stop           0.038631
# pow_gain        0.4944347
# tau          1.017288e-05
# w_loss           6.060065
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1370.058
# k                       5
# N                     280
# bic               2768.29
# theta                  30
# p_stay          0.6322508
# p_stop           0.038631
# pow_gain        0.4944347
# tau          1.017288e-05
# w_loss           6.060065
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1370.058
# k                       5
# N                     280
# bic               2768.29
# theta                  30
# p_stay          0.6322508
# p_stop           0.038631
# pow_gain        0.4944347
# tau          1.017288e-05
# w_loss           6.060065
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1370.057914  5  280  2768.289775     30  0.632251
#
#      p_stop  pow_gain      tau    w_loss
# 0  0.038631  0.494435  0.00001  6.060065
# frey_individual_planned_geom_session=S16(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1376.019
# k                              5
# N                            280
# bic                     2780.211
# theta                         30
# p_stay               2.90925e-05
# p_stop                0.03674895
# prelec_elevation        1.414012
# prelec_gamma           0.9973922
# tau                 3.383426e-05
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1376.019
# k                              5
# N                            280
# bic                     2780.211
# theta                         30
# p_stay               2.90925e-05
# p_stop                0.03674895
# prelec_elevation        1.414012
# prelec_gamma           0.9973922
# tau                 3.383426e-05
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1376.019
# k                              5
# N                            280
# bic                     2780.211
# theta                         30
# p_stay               2.90925e-05
# p_stop                0.03674895
# prelec_elevation        1.414012
# prelec_gamma           0.9973922
# tau                 3.383426e-05
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1376.018651  5  280  2780.211251     30  0.000029
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.036749          1.414012      0.997392  0.000034
# frey_individual_planned_geom_session=S16(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1375.399
# k                       5
# N                     280
# bic              2778.972
# theta                  30
# p_stay       1.759295e-05
# p_stop         0.03674895
# pow_gain        0.6407931
# tau          1.185954e-05
# w_loss            3.41697
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1375.399
# k                       5
# N                     280
# bic              2778.972
# theta                  30
# p_stay       1.759295e-05
# p_stop         0.03674895
# pow_gain        0.6407931
# tau          1.185954e-05
# w_loss            3.41697
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1375.399
# k                       5
# N                     280
# bic              2778.972
# theta                  30
# p_stay       1.759295e-05
# p_stop         0.03674895
# pow_gain        0.6407931
# tau          1.185954e-05
# w_loss            3.41697
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1375.399038  5  280  2778.972024     30  0.000018
#
#      p_stop  pow_gain       tau   w_loss
# 0  0.036749  0.640793  0.000012  3.41697
# frey_individual_planned_geom_session=S17(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                    0
# success                   True
# nllh                   1372.59
# k                            5
# N                          278
# bic                   2773.318
# theta                       30
# p_stay              0.09693554
# p_stop              0.03637182
# prelec_elevation      1.482544
# prelec_gamma           1.11272
# tau                  0.7090455
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                    1
# success                   True
# nllh                   1372.59
# k                            5
# N                          278
# bic                   2773.318
# theta                       30
# p_stay              0.09693554
# p_stop              0.03637182
# prelec_elevation      1.482544
# prelec_gamma           1.11272
# tau                  0.7090455
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                    2
# success                   True
# nllh                   1372.59
# k                            5
# N                          278
# bic                   2773.318
# theta                       30
# p_stay              0.09693554
# p_stop              0.03637182
# prelec_elevation      1.482544
# prelec_gamma           1.11272
# tau                  0.7090455
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1372.590031  5  278  2773.318168     30  0.096936
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.036372          1.482544       1.11272  0.709045
# frey_individual_planned_geom_session=S17(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh             1375.9
# k                     5
# N                   278
# bic            2779.938
# theta                30
# p_stay       0.06785607
# p_stop       0.03637182
# pow_gain      0.6946461
# tau           0.3848636
# w_loss         1.230896
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh             1375.9
# k                     5
# N                   278
# bic            2779.938
# theta                30
# p_stay       0.06785607
# p_stop       0.03637182
# pow_gain      0.6946461
# tau           0.3848636
# w_loss         1.230896
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh             1375.9
# k                     5
# N                   278
# bic            2779.938
# theta                30
# p_stay       0.06785607
# p_stop       0.03637182
# pow_gain      0.6946461
# tau           0.3848636
# w_loss         1.230896
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1375.899868  5  278  2779.937842     30  0.067856
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.036372  0.694646  0.384864  1.230896
# frey_individual_planned_geom_session=S18(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                    0
# success                   True
# nllh                  1348.199
# k                            5
# N                          280
# bic                   2724.573
# theta                       30
# p_stay              0.03384136
# p_stop              0.04089975
# prelec_elevation      1.325076
# prelec_gamma          1.102863
# tau                  0.3875643
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                    1
# success                   True
# nllh                  1348.199
# k                            5
# N                          280
# bic                   2724.573
# theta                       30
# p_stay              0.03384136
# p_stop              0.04089975
# prelec_elevation      1.325076
# prelec_gamma          1.102863
# tau                  0.3875643
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                    2
# success                   True
# nllh                  1348.199
# k                            5
# N                          280
# bic                   2724.573
# theta                       30
# p_stay              0.03384136
# p_stop              0.04089975
# prelec_elevation      1.325076
# prelec_gamma          1.102863
# tau                  0.3875643
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1348.199392  5  280  2724.572732     30  0.033841
#
#    p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.0409          1.325076      1.102863  0.387564
# frey_individual_planned_geom_session=S18(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration              0
# success             True
# nllh            1349.751
# k                      5
# N                    280
# bic             2727.675
# theta                 30
# p_stay       0.008696969
# p_stop        0.04089975
# pow_gain       0.7042356
# tau            0.1673887
# w_loss          2.835336
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration              1
# success             True
# nllh            1349.751
# k                      5
# N                    280
# bic             2727.675
# theta                 30
# p_stay       0.008696969
# p_stop        0.04089975
# pow_gain       0.7042356
# tau            0.1673887
# w_loss          2.835336
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration              2
# success             True
# nllh            1349.751
# k                      5
# N                    280
# bic             2727.675
# theta                 30
# p_stay       0.008696969
# p_stop        0.04089975
# pow_gain       0.7042356
# tau            0.1673887
# w_loss          2.835336
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1349.750738  5  280  2727.675424     30  0.008697
#
#    p_stop  pow_gain       tau    w_loss
# 0  0.0409  0.704236  0.167389  2.835336
# frey_individual_planned_geom_session=S19(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1307.689
# k                              5
# N                            268
# bic                     2643.333
# theta                         30
# p_stay                 0.7166897
# p_stop                0.03834088
# prelec_elevation        1.756111
# prelec_gamma            1.066845
# tau                 2.050106e-05
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1307.689
# k                              5
# N                            268
# bic                     2643.333
# theta                         30
# p_stay                 0.7166897
# p_stop                0.03834088
# prelec_elevation        1.756111
# prelec_gamma            1.066845
# tau                 2.050106e-05
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1307.689
# k                              5
# N                            268
# bic                     2643.333
# theta                         30
# p_stay                 0.7166897
# p_stop                0.03834088
# prelec_elevation        1.756111
# prelec_gamma            1.066845
# tau                 2.050106e-05
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta   p_stay  \
# 0          0    True  1307.689111  5  268  2643.333156     30  0.71669
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.038341          1.756111      1.066845  0.000021
# frey_individual_planned_geom_session=S19(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1308.809
# k                       5
# N                     268
# bic              2645.573
# theta                  30
# p_stay          0.6852084
# p_stop         0.03834088
# pow_gain        0.5599293
# tau          9.681289e-06
# w_loss           7.205963
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1308.809
# k                       5
# N                     268
# bic              2645.573
# theta                  30
# p_stay          0.6852084
# p_stop         0.03834088
# pow_gain        0.5599293
# tau          9.681289e-06
# w_loss           7.205963
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1308.809
# k                       5
# N                     268
# bic              2645.573
# theta                  30
# p_stay          0.6852084
# p_stop         0.03834088
# pow_gain        0.5599293
# tau          9.681289e-06
# w_loss           7.205963
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1308.808972  5  268  2645.572879     30  0.685208
#
#      p_stop  pow_gain      tau    w_loss
# 0  0.038341  0.559929  0.00001  7.205963
# frey_individual_planned_geom_session=S20(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                    0
# success                   True
# nllh                  1268.611
# k                            5
# N                          256
# bic                   2564.949
# theta                       30
# p_stay               0.6668304
# p_stop              0.03705371
# prelec_elevation      1.431651
# prelec_gamma          1.040983
# tau                  0.7211674
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                    1
# success                   True
# nllh                  1268.611
# k                            5
# N                          256
# bic                   2564.949
# theta                       30
# p_stay               0.6668304
# p_stop              0.03705371
# prelec_elevation      1.431651
# prelec_gamma          1.040983
# tau                  0.7211674
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                    2
# success                   True
# nllh                  1268.611
# k                            5
# N                          256
# bic                   2564.949
# theta                       30
# p_stay               0.6668304
# p_stop              0.03705371
# prelec_elevation      1.431651
# prelec_gamma          1.040983
# tau                  0.7211674
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta   p_stay  \
# 0          0    True  1268.611445  5  256  2564.948776     30  0.66683
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.037054          1.431651      1.040983  0.721167
# frey_individual_planned_geom_session=S20(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           1269.426
# k                     5
# N                   256
# bic            2566.578
# theta                30
# p_stay        0.6663718
# p_stop       0.03705371
# pow_gain      0.7307862
# tau            0.655694
# w_loss         2.474169
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           1269.426
# k                     5
# N                   256
# bic            2566.578
# theta                30
# p_stay        0.6663718
# p_stop       0.03705371
# pow_gain      0.7307862
# tau            0.655694
# w_loss         2.474169
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           1269.426
# k                     5
# N                   256
# bic            2566.578
# theta                30
# p_stay        0.6663718
# p_stop       0.03705371
# pow_gain      0.7307862
# tau            0.655694
# w_loss         2.474169
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1269.426085  5  256  2566.578057     30  0.666372
#
#      p_stop  pow_gain       tau    w_loss
# 0  0.037054  0.730786  0.655694  2.474169
# frey_individual_planned_geom_session=S21(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1133.437
# k                              5
# N                            232
# bic                     2294.108
# theta                         30
# p_stay                 0.1249682
# p_stop                0.03691285
# prelec_elevation         1.57042
# prelec_gamma           0.9704624
# tau                 3.864827e-05
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1133.437
# k                              5
# N                            232
# bic                     2294.108
# theta                         30
# p_stay                 0.1249682
# p_stop                0.03691285
# prelec_elevation         1.57042
# prelec_gamma           0.9704624
# tau                 3.864827e-05
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1133.437
# k                              5
# N                            232
# bic                     2294.108
# theta                         30
# p_stay                 0.1249682
# p_stop                0.03691285
# prelec_elevation         1.57042
# prelec_gamma           0.9704624
# tau                 3.864827e-05
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta    p_stay  \
# 0          0    True  1133.437276  5  232  2294.108239     30  0.124968
#
#      p_stop  prelec_elevation  prelec_gamma       tau
# 0  0.036913           1.57042      0.970462  0.000039
# frey_individual_planned_geom_session=S21(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1133.948
# k                       5
# N                     232
# bic              2295.129
# theta                  30
# p_stay       6.607296e-05
# p_stop         0.03691285
# pow_gain        0.5286355
# tau          2.008608e-07
# w_loss           5.838046
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1133.948
# k                       5
# N                     232
# bic              2295.129
# theta                  30
# p_stay       6.607296e-05
# p_stop         0.03691285
# pow_gain        0.5286355
# tau          2.008608e-07
# w_loss           5.838046
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1133.948
# k                       5
# N                     232
# bic              2295.129
# theta                  30
# p_stay       6.607296e-05
# p_stop         0.03691285
# pow_gain        0.5286355
# tau          2.008608e-07
# w_loss           5.838046
# Name: 2, dtype: object
#    iteration success         nllh  k    N        bic  theta    p_stay  \
# 0          0    True  1133.947806  5  232  2295.1293     30  0.000066
#
#      p_stop  pow_gain           tau    w_loss
# 0  0.036913  0.528635  2.008608e-07  5.838046

# %% [markdown]
# ### Truncated normal

# %%
for sid in data.session.unique():

    SIM_ID = 'frey_individual_planned_session=%s' % sid

    for parset in PARSETS_NORMAL:

        fitting = {p: PARS[p] for p in parset}
        fitting['mu'][2] = data[data.session==sid].samplesize.mean()
        
        # initialize the model
        m = CHASEAlternateStoppingModel(drift='cpt',
                                        startdist='laplace',
                                        stoprule='truncatednormal',
                                        problems=problems)

        # fit
        results = fit_mlh(m, problems, data[data.session==sid], 
                          SIM_ID, FIXED, fitting, niter=N_ITER, outdir=OUTDIR,
                          method='Powell')

        print results.sort('nllh').head(1)
# Out:
# frey_individual_planned_session=S1(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                     0
# success                    True
# nllh                   1394.348
# k                             6
# N                           280
# bic                    2822.504
# theta                        30
# mu                  0.001042674
# p_stay                0.7778684
# prelec_elevation       1.746847
# prelec_gamma           1.234247
# sc                     34.31454
# tau                    0.452512
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                     1
# success                    True
# nllh                   1394.348
# k                             6
# N                           280
# bic                    2822.504
# theta                        30
# mu                  0.001042674
# p_stay                0.7778684
# prelec_elevation       1.746847
# prelec_gamma           1.234247
# sc                     34.31454
# tau                    0.452512
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                     2
# success                    True
# nllh                   1394.348
# k                             6
# N                           280
# bic                    2822.504
# theta                        30
# mu                  0.001042674
# p_stay                0.7778684
# prelec_elevation       1.746847
# prelec_gamma           1.234247
# sc                     34.31454
# tau                    0.452512
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1394.347717  6  280  2822.504172     30  0.001043
#
#      p_stay  prelec_elevation  prelec_gamma         sc       tau
# 0  0.777868          1.746847      1.234247  34.314542  0.452512
# frey_individual_planned_session=S1(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1396.012
# k                       6
# N                     280
# bic              2825.833
# theta                  30
# mu           0.0004133442
# p_stay          0.5430687
# pow_gain        0.6494683
# sc               34.34342
# tau             0.2080727
# w_loss           14.12351
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1396.012
# k                       6
# N                     280
# bic              2825.833
# theta                  30
# mu           0.0004133442
# p_stay          0.5430687
# pow_gain        0.6494683
# sc               34.34342
# tau             0.2080727
# w_loss           14.12351
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1396.012
# k                       6
# N                     280
# bic              2825.833
# theta                  30
# mu           0.0004133442
# p_stay          0.5430687
# pow_gain        0.6494683
# sc               34.34342
# tau             0.2080727
# w_loss           14.12351
# Name: 2, dtype: object
#    iteration success        nllh  k    N          bic  theta        mu  \
# 0          0    True  1396.01207  6  280  2825.832877     30  0.000413
#
#      p_stay  pow_gain         sc       tau     w_loss
# 0  0.543069  0.649468  34.343423  0.208073  14.123515
# frey_individual_planned_session=S2(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1425.303
# k                              6
# N                            279
# bic                     2884.394
# theta                         30
# mu                  3.724401e-05
# p_stay                 0.1783413
# prelec_elevation         1.39174
# prelec_gamma           0.8459216
# sc                      35.72851
# tau                 2.379002e-09
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1425.303
# k                              6
# N                            279
# bic                     2884.394
# theta                         30
# mu                  3.724401e-05
# p_stay                 0.1783413
# prelec_elevation         1.39174
# prelec_gamma           0.8459216
# sc                      35.72851
# tau                 2.379002e-09
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1425.303
# k                              6
# N                            279
# bic                     2884.394
# theta                         30
# mu                  3.724401e-05
# p_stay                 0.1783413
# prelec_elevation         1.39174
# prelec_gamma           0.8459216
# sc                      35.72851
# tau                 2.379002e-09
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1425.303468  6  279  2884.394207     30  0.000037
#
#      p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.178341           1.39174      0.845922  35.728514  2.379002e-09
# frey_individual_planned_session=S2(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1424.764
# k                       6
# N                     279
# bic              2883.315
# theta                  30
# mu           3.726097e-05
# p_stay          0.5464468
# pow_gain        0.5859142
# sc               35.72852
# tau          1.851575e-06
# w_loss           6.654293
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1424.764
# k                       6
# N                     279
# bic              2883.315
# theta                  30
# mu           3.726097e-05
# p_stay          0.5464468
# pow_gain        0.5859142
# sc               35.72852
# tau          1.851575e-06
# w_loss           6.654293
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1424.764
# k                       6
# N                     279
# bic              2883.315
# theta                  30
# mu           3.726097e-05
# p_stay          0.5464468
# pow_gain        0.5859142
# sc               35.72852
# tau          1.851575e-06
# w_loss           6.654293
# Name: 2, dtype: object
#    iteration success        nllh  k    N         bic  theta        mu  \
# 0          0    True  1424.76383  6  279  2883.31493     30  0.000037
#
#      p_stay  pow_gain         sc       tau    w_loss
# 0  0.546447  0.585914  35.728516  0.000002  6.654293
# frey_individual_planned_session=S3(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                     0
# success                    True
# nllh                   1372.563
# k                             6
# N                           280
# bic                    2778.934
# theta                        30
# mu                     5.595776
# p_stay              5.36783e-07
# prelec_elevation       1.405762
# prelec_gamma          0.9752722
# sc                     31.79125
# tau                   0.7823892
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                     1
# success                    True
# nllh                   1372.563
# k                             6
# N                           280
# bic                    2778.934
# theta                        30
# mu                     5.595776
# p_stay              5.36783e-07
# prelec_elevation       1.405762
# prelec_gamma          0.9752722
# sc                     31.79125
# tau                   0.7823892
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                     2
# success                    True
# nllh                   1372.563
# k                             6
# N                           280
# bic                    2778.934
# theta                        30
# mu                     5.595776
# p_stay              5.36783e-07
# prelec_elevation       1.405762
# prelec_gamma          0.9752722
# sc                     31.79125
# tau                   0.7823892
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1372.562545  6  280  2778.933827     30  5.595776
#
#          p_stay  prelec_elevation  prelec_gamma         sc       tau
# 0  5.367830e-07          1.405762      0.975272  31.791248  0.782389
# frey_individual_planned_session=S3(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1373.148
# k                       6
# N                     280
# bic              2780.105
# theta                  30
# mu               5.595776
# p_stay       3.170849e-07
# pow_gain        0.6369196
# sc               31.79125
# tau             0.7321145
# w_loss           7.175628
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1373.148
# k                       6
# N                     280
# bic              2780.105
# theta                  30
# mu               5.595776
# p_stay       3.170849e-07
# pow_gain        0.6369196
# sc               31.79125
# tau             0.7321145
# w_loss           7.175628
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1373.148
# k                       6
# N                     280
# bic              2780.105
# theta                  30
# mu               5.595776
# p_stay       3.170849e-07
# pow_gain        0.6369196
# sc               31.79125
# tau             0.7321145
# w_loss           7.175628
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1373.148379  6  280  2780.105496     30  5.595776
#
#          p_stay  pow_gain         sc       tau    w_loss
# 0  3.170849e-07   0.63692  31.791248  0.732114  7.175628
# frey_individual_planned_session=S4(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1405.917
# k                              6
# N                            280
# bic                     2845.643
# theta                         30
# mu                   0.003755784
# p_stay                 0.6485713
# prelec_elevation        1.272037
# prelec_gamma            1.097811
# sc                      37.49981
# tau                 1.095708e-09
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1405.917
# k                              6
# N                            280
# bic                     2845.643
# theta                         30
# mu                   0.003755784
# p_stay                 0.6485713
# prelec_elevation        1.272037
# prelec_gamma            1.097811
# sc                      37.49981
# tau                 1.095708e-09
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1405.917
# k                              6
# N                            280
# bic                     2845.643
# theta                         30
# mu                   0.003755784
# p_stay                 0.6485713
# prelec_elevation        1.272037
# prelec_gamma            1.097811
# sc                      37.49981
# tau                 1.095708e-09
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1405.917283  6  280  2845.643304     30  0.003756
#
#      p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.648571          1.272037      1.097811  37.499808  1.095708e-09
# frey_individual_planned_session=S4(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1406.815
# k                       6
# N                     280
# bic              2847.439
# theta                  30
# mu            0.003755785
# p_stay          0.2482566
# pow_gain        0.7922179
# sc               37.49981
# tau          5.881004e-10
# w_loss           8.911926
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1406.815
# k                       6
# N                     280
# bic              2847.439
# theta                  30
# mu            0.003755785
# p_stay          0.2482566
# pow_gain        0.7922179
# sc               37.49981
# tau          5.881004e-10
# w_loss           8.911926
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1406.815
# k                       6
# N                     280
# bic              2847.439
# theta                  30
# mu            0.003755785
# p_stay          0.2482566
# pow_gain        0.7922179
# sc               37.49981
# tau          5.881004e-10
# w_loss           8.911926
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1406.815259  6  280  2847.439256     30  0.003756
#
#      p_stay  pow_gain         sc           tau    w_loss
# 0  0.248257  0.792218  37.499808  5.881004e-10  8.911926
# frey_individual_planned_session=S5(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1382.527
# k                              6
# N                            280
# bic                     2798.863
# theta                         30
# mu                   0.001161655
# p_stay                 0.2488275
# prelec_elevation        1.378472
# prelec_gamma           0.9809184
# sc                      34.76235
# tau                 3.409044e-10
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1382.527
# k                              6
# N                            280
# bic                     2798.863
# theta                         30
# mu                   0.001161655
# p_stay                 0.2488275
# prelec_elevation        1.378472
# prelec_gamma           0.9809184
# sc                      34.76235
# tau                 3.409044e-10
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1382.527
# k                              6
# N                            280
# bic                     2798.863
# theta                         30
# mu                   0.001161655
# p_stay                 0.2488275
# prelec_elevation        1.378472
# prelec_gamma           0.9809184
# sc                      34.76235
# tau                 3.409044e-10
# Name: 2, dtype: object
#    iteration success         nllh  k    N         bic  theta        mu  \
# 0          0    True  1382.527151  6  280  2798.86304     30  0.001162
#
#      p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.248828          1.378472      0.980918  34.762353  3.409044e-10
# frey_individual_planned_session=S5(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1382.667
# k                       6
# N                     280
# bic              2799.143
# theta                  30
# mu            0.001161645
# p_stay          0.3592214
# pow_gain        0.6887821
# sc               34.76235
# tau          3.409044e-10
# w_loss           3.001752
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1382.667
# k                       6
# N                     280
# bic              2799.143
# theta                  30
# mu            0.001161645
# p_stay          0.3592214
# pow_gain        0.6887821
# sc               34.76235
# tau          3.409044e-10
# w_loss           3.001752
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1382.667
# k                       6
# N                     280
# bic              2799.143
# theta                  30
# mu            0.001161645
# p_stay          0.3592214
# pow_gain        0.6887821
# sc               34.76235
# tau          3.409044e-10
# w_loss           3.001752
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1382.666896  6  280  2799.142529     30  0.001162
#
#      p_stay  pow_gain         sc           tau    w_loss
# 0  0.359221  0.688782  34.762353  3.409044e-10  3.001752
# frey_individual_planned_session=S6(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                     0
# success                    True
# nllh                   1361.499
# k                             6
# N                           280
# bic                    2756.806
# theta                        30
# mu                  0.004048094
# p_stay                0.3454119
# prelec_elevation       1.573237
# prelec_gamma          0.9932859
# sc                     32.91272
# tau                 0.007000649
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                     1
# success                    True
# nllh                   1361.499
# k                             6
# N                           280
# bic                    2756.806
# theta                        30
# mu                  0.004048094
# p_stay                0.3454119
# prelec_elevation       1.573237
# prelec_gamma          0.9932859
# sc                     32.91272
# tau                 0.007000649
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                     2
# success                    True
# nllh                   1361.499
# k                             6
# N                           280
# bic                    2756.806
# theta                        30
# mu                  0.004048094
# p_stay                0.3454119
# prelec_elevation       1.573237
# prelec_gamma          0.9932859
# sc                     32.91272
# tau                 0.007000649
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1361.498542  6  280  2756.805822     30  0.004048
#
#      p_stay  prelec_elevation  prelec_gamma         sc       tau
# 0  0.345412          1.573237      0.993286  32.912725  0.007001
# frey_individual_planned_session=S6(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1361.442
# k                       6
# N                     280
# bic              2756.693
# theta                  30
# mu            0.004048096
# p_stay          0.3255392
# pow_gain        0.5765807
# sc               32.91272
# tau          1.633587e-06
# w_loss           8.032977
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1361.442
# k                       6
# N                     280
# bic              2756.693
# theta                  30
# mu            0.004048096
# p_stay          0.3255392
# pow_gain        0.5765807
# sc               32.91272
# tau          1.633587e-06
# w_loss           8.032977
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1361.442
# k                       6
# N                     280
# bic              2756.693
# theta                  30
# mu            0.004048096
# p_stay          0.3255392
# pow_gain        0.5765807
# sc               32.91272
# tau          1.633587e-06
# w_loss           8.032977
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1361.442345  6  280  2756.693428     30  0.004048
#
#      p_stay  pow_gain         sc       tau    w_loss
# 0  0.325539  0.576581  32.912725  0.000002  8.032977
# frey_individual_planned_session=S7(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1400.333
# k                              6
# N                            280
# bic                     2834.475
# theta                         30
# mu                   0.002149979
# p_stay                 0.3610252
# prelec_elevation        1.305581
# prelec_gamma            1.115435
# sc                      37.49662
# tau                 3.409044e-10
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1400.333
# k                              6
# N                            280
# bic                     2834.475
# theta                         30
# mu                   0.002149979
# p_stay                 0.3610252
# prelec_elevation        1.305581
# prelec_gamma            1.115435
# sc                      37.49662
# tau                 3.409044e-10
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1400.333
# k                              6
# N                            280
# bic                     2834.475
# theta                         30
# mu                   0.002149979
# p_stay                 0.3610252
# prelec_elevation        1.305581
# prelec_gamma            1.115435
# sc                      37.49662
# tau                 3.409044e-10
# Name: 2, dtype: object
#    iteration success         nllh  k    N         bic  theta       mu  \
# 0          0    True  1400.333166  6  280  2834.47507     30  0.00215
#
#      p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.361025          1.305581      1.115435  37.496623  3.409044e-10
# frey_individual_planned_session=S7(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1402.459
# k                       6
# N                     280
# bic              2838.727
# theta                  30
# mu            0.002149979
# p_stay          0.2447047
# pow_gain        0.7210363
# sc               37.49662
# tau          3.409044e-10
# w_loss           5.381437
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1402.459
# k                       6
# N                     280
# bic              2838.727
# theta                  30
# mu            0.002149979
# p_stay          0.2447047
# pow_gain        0.7210363
# sc               37.49662
# tau          3.409044e-10
# w_loss           5.381437
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1402.459
# k                       6
# N                     280
# bic              2838.727
# theta                  30
# mu            0.002149979
# p_stay          0.2447047
# pow_gain        0.7210363
# sc               37.49662
# tau          3.409044e-10
# w_loss           5.381437
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta       mu  \
# 0          0    True  1402.459312  6  280  2838.727362     30  0.00215
#
#      p_stay  pow_gain         sc           tau    w_loss
# 0  0.244705  0.721036  37.496623  3.409044e-10  5.381437
# frey_individual_planned_session=S8(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1355.032
# k                              6
# N                            278
# bic                      2743.83
# theta                         30
# mu                    0.02297815
# p_stay               0.004369512
# prelec_elevation        1.214709
# prelec_gamma            1.193754
# sc                      34.56493
# tau                 7.349748e-09
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1355.032
# k                              6
# N                            278
# bic                      2743.83
# theta                         30
# mu                    0.02297815
# p_stay               0.004369512
# prelec_elevation        1.214709
# prelec_gamma            1.193754
# sc                      34.56493
# tau                 7.349748e-09
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1355.032
# k                              6
# N                            278
# bic                      2743.83
# theta                         30
# mu                    0.02297815
# p_stay               0.004369512
# prelec_elevation        1.214709
# prelec_gamma            1.193754
# sc                      34.56493
# tau                 7.349748e-09
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1355.032013  6  278  2743.829752     30  0.022978
#
#     p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.00437          1.214709      1.193754  34.564926  7.349748e-09
# frey_individual_planned_session=S8(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh              1362.07
# k                       6
# N                     278
# bic              2757.905
# theta                  30
# mu             0.02297815
# p_stay       1.749773e-10
# pow_gain        0.7855621
# sc               34.56493
# tau          3.284009e-09
# w_loss           5.802051
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh              1362.07
# k                       6
# N                     278
# bic              2757.905
# theta                  30
# mu             0.02297815
# p_stay       1.749773e-10
# pow_gain        0.7855621
# sc               34.56493
# tau          3.284009e-09
# w_loss           5.802051
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh              1362.07
# k                       6
# N                     278
# bic              2757.905
# theta                  30
# mu             0.02297815
# p_stay       1.749773e-10
# pow_gain        0.7855621
# sc               34.56493
# tau          3.284009e-09
# w_loss           5.802051
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1362.069534  6  278  2757.904795     30  0.022978
#
#          p_stay  pow_gain         sc           tau    w_loss
# 0  1.749773e-10  0.785562  34.564926  3.284009e-09  5.802051
# frey_individual_planned_session=S9(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1364.372
# k                              6
# N                            280
# bic                     2762.554
# theta                         30
# mu                   0.002449705
# p_stay              9.855546e-12
# prelec_elevation        1.173007
# prelec_gamma             1.00631
# sc                       32.5555
# tau                    0.3230937
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1364.372
# k                              6
# N                            280
# bic                     2762.554
# theta                         30
# mu                   0.002449705
# p_stay              9.855546e-12
# prelec_elevation        1.173007
# prelec_gamma             1.00631
# sc                       32.5555
# tau                    0.3230937
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1364.372
# k                              6
# N                            280
# bic                     2762.554
# theta                         30
# mu                   0.002449705
# p_stay              9.855546e-12
# prelec_elevation        1.173007
# prelec_gamma             1.00631
# sc                       32.5555
# tau                    0.3230937
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta       mu  \
# 0          0    True  1364.372408  6  280  2762.553553     30  0.00245
#
#          p_stay  prelec_elevation  prelec_gamma         sc       tau
# 0  9.855546e-12          1.173007       1.00631  32.555502  0.323094
# frey_individual_planned_session=S9(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1364.114
# k                       6
# N                     280
# bic              2762.037
# theta                  30
# mu            0.002449967
# p_stay       9.033663e-11
# pow_gain        0.8169684
# sc                32.5555
# tau             0.3527942
# w_loss           7.906389
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1364.114
# k                       6
# N                     280
# bic              2762.037
# theta                  30
# mu            0.002449967
# p_stay       9.033663e-11
# pow_gain        0.8169684
# sc                32.5555
# tau             0.3527942
# w_loss           7.906389
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1364.114
# k                       6
# N                     280
# bic              2762.037
# theta                  30
# mu            0.002449967
# p_stay       9.033663e-11
# pow_gain        0.8169684
# sc                32.5555
# tau             0.3527942
# w_loss           7.906389
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta       mu  \
# 0          0    True  1364.113957  6  280  2762.036651     30  0.00245
#
#          p_stay  pow_gain         sc       tau    w_loss
# 0  9.033663e-11  0.816968  32.555502  0.352794  7.906389
# frey_individual_planned_session=S10(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1398.116
# k                              6
# N                            279
# bic                     2830.019
# theta                         30
# mu                  0.0005927813
# p_stay                 0.8038131
# prelec_elevation        1.989926
# prelec_gamma             1.08892
# sc                      37.76339
# tau                 7.837982e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1398.116
# k                              6
# N                            279
# bic                     2830.019
# theta                         30
# mu                  0.0005927813
# p_stay                 0.8038131
# prelec_elevation        1.989926
# prelec_gamma             1.08892
# sc                      37.76339
# tau                 7.837982e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1398.116
# k                              6
# N                            279
# bic                     2830.019
# theta                         30
# mu                  0.0005927813
# p_stay                 0.8038131
# prelec_elevation        1.989926
# prelec_gamma             1.08892
# sc                      37.76339
# tau                 7.837982e-08
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1398.115837  6  279  2830.018944     30  0.000593
#
#      p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.803813          1.989926       1.08892  37.763392  7.837982e-08
# frey_individual_planned_session=S10(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh               1396.7
# k                       6
# N                     279
# bic              2827.187
# theta                  30
# mu           0.0005927813
# p_stay         0.08779383
# pow_gain        0.4867503
# sc               37.76339
# tau             0.3876533
# w_loss           10.57782
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh               1396.7
# k                       6
# N                     279
# bic              2827.187
# theta                  30
# mu           0.0005927813
# p_stay         0.08779383
# pow_gain        0.4867503
# sc               37.76339
# tau             0.3876533
# w_loss           10.57782
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh               1396.7
# k                       6
# N                     279
# bic              2827.187
# theta                  30
# mu           0.0005927813
# p_stay         0.08779383
# pow_gain        0.4867503
# sc               37.76339
# tau             0.3876533
# w_loss           10.57782
# Name: 2, dtype: object
#    iteration success        nllh  k    N          bic  theta        mu  \
# 0          0    True  1396.69992  6  279  2827.187111     30  0.000593
#
#      p_stay  pow_gain         sc       tau     w_loss
# 0  0.087794   0.48675  37.763392  0.387653  10.577824
# frey_individual_planned_session=S11(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1376.606
# k                              6
# N                            280
# bic                      2787.02
# theta                         30
# mu                  3.184546e-06
# p_stay                0.09721923
# prelec_elevation        1.152667
# prelec_gamma            1.176976
# sc                      34.72808
# tau                     0.465375
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1376.606
# k                              6
# N                            280
# bic                      2787.02
# theta                         30
# mu                  3.184546e-06
# p_stay                0.09721923
# prelec_elevation        1.152667
# prelec_gamma            1.176976
# sc                      34.72808
# tau                     0.465375
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1376.606
# k                              6
# N                            280
# bic                      2787.02
# theta                         30
# mu                  3.184546e-06
# p_stay                0.09721923
# prelec_elevation        1.152667
# prelec_gamma            1.176976
# sc                      34.72808
# tau                     0.465375
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1376.605687  6  280  2787.020112     30  0.000003
#
#      p_stay  prelec_elevation  prelec_gamma        sc       tau
# 0  0.097219          1.152667      1.176976  34.72808  0.465375
# frey_individual_planned_session=S11(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1378.637
# k                       6
# N                     280
# bic              2791.082
# theta                  30
# mu           3.184209e-06
# p_stay        0.008795191
# pow_gain        0.7669328
# sc               34.72808
# tau             0.3455471
# w_loss           9.782385
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1378.637
# k                       6
# N                     280
# bic              2791.082
# theta                  30
# mu           3.184209e-06
# p_stay        0.008795191
# pow_gain        0.7669328
# sc               34.72808
# tau             0.3455471
# w_loss           9.782385
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1378.637
# k                       6
# N                     280
# bic              2791.082
# theta                  30
# mu           3.184209e-06
# p_stay        0.008795191
# pow_gain        0.7669328
# sc               34.72808
# tau             0.3455471
# w_loss           9.782385
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1378.636602  6  280  2791.081941     30  0.000003
#
#      p_stay  pow_gain        sc       tau    w_loss
# 0  0.008795  0.766933  34.72808  0.345547  9.782385
# frey_individual_planned_session=S12(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1406.397
# k                              6
# N                            279
# bic                     2846.581
# theta                         30
# mu                  9.313549e-05
# p_stay                 0.8694043
# prelec_elevation        1.920898
# prelec_gamma            1.097478
# sc                      35.79977
# tau                    0.5611712
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1406.397
# k                              6
# N                            279
# bic                     2846.581
# theta                         30
# mu                  9.313549e-05
# p_stay                 0.8694043
# prelec_elevation        1.920898
# prelec_gamma            1.097478
# sc                      35.79977
# tau                    0.5611712
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1406.397
# k                              6
# N                            279
# bic                     2846.581
# theta                         30
# mu                  9.313549e-05
# p_stay                 0.8694043
# prelec_elevation        1.920898
# prelec_gamma            1.097478
# sc                      35.79977
# tau                    0.5611712
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1406.396797  6  279  2846.580864     30  0.000093
#
#      p_stay  prelec_elevation  prelec_gamma         sc       tau
# 0  0.869404          1.920898      1.097478  35.799766  0.561171
# frey_individual_planned_session=S12(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1407.887
# k                       6
# N                     279
# bic               2849.56
# theta                  30
# mu           9.344461e-05
# p_stay          0.8470623
# pow_gain        0.5964687
# sc               35.79979
# tau          5.602518e-10
# w_loss           11.35172
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1407.887
# k                       6
# N                     279
# bic               2849.56
# theta                  30
# mu           9.344461e-05
# p_stay          0.8470623
# pow_gain        0.5964687
# sc               35.79979
# tau          5.602518e-10
# w_loss           11.35172
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1407.887
# k                       6
# N                     279
# bic               2849.56
# theta                  30
# mu           9.344461e-05
# p_stay          0.8470623
# pow_gain        0.5964687
# sc               35.79979
# tau          5.602518e-10
# w_loss           11.35172
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1407.886563  6  279  2849.560397     30  0.000093
#
#      p_stay  pow_gain         sc           tau     w_loss
# 0  0.847062  0.596469  35.799788  5.602518e-10  11.351716
# frey_individual_planned_session=S13(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1371.512
# k                              6
# N                            280
# bic                     2776.833
# theta                         30
# mu                  2.019787e-05
# p_stay              5.321073e-10
# prelec_elevation        1.476393
# prelec_gamma             0.93427
# sc                       34.7592
# tau                 3.409044e-10
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1371.512
# k                              6
# N                            280
# bic                     2776.833
# theta                         30
# mu                  2.019787e-05
# p_stay              5.321073e-10
# prelec_elevation        1.476393
# prelec_gamma             0.93427
# sc                       34.7592
# tau                 3.409044e-10
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1371.512
# k                              6
# N                            280
# bic                     2776.833
# theta                         30
# mu                  2.019787e-05
# p_stay              5.321073e-10
# prelec_elevation        1.476393
# prelec_gamma             0.93427
# sc                       34.7592
# tau                 3.409044e-10
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta       mu  \
# 0          0    True  1371.512143  6  280  2776.833024     30  0.00002
#
#          p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  5.321073e-10          1.476393       0.93427  34.759198  3.409044e-10
# frey_individual_planned_session=S13(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh              1371.75
# k                       6
# N                     280
# bic               2777.31
# theta                  30
# mu            2.01984e-05
# p_stay       2.976611e-10
# pow_gain        0.5841524
# sc                34.7592
# tau          3.409044e-10
# w_loss           8.089015
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh              1371.75
# k                       6
# N                     280
# bic               2777.31
# theta                  30
# mu            2.01984e-05
# p_stay       2.976611e-10
# pow_gain        0.5841524
# sc                34.7592
# tau          3.409044e-10
# w_loss           8.089015
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh              1371.75
# k                       6
# N                     280
# bic               2777.31
# theta                  30
# mu            2.01984e-05
# p_stay       2.976611e-10
# pow_gain        0.5841524
# sc                34.7592
# tau          3.409044e-10
# w_loss           8.089015
# Name: 2, dtype: object
#    iteration success        nllh  k    N          bic  theta       mu  \
# 0          0    True  1371.75041  6  280  2777.309558     30  0.00002
#
#          p_stay  pow_gain         sc           tau    w_loss
# 0  2.976611e-10  0.584152  34.759198  3.409044e-10  8.089015
# frey_individual_planned_session=S14(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1369.997
# k                              6
# N                            280
# bic                     2773.802
# theta                         30
# mu                    0.00230579
# p_stay              6.431507e-11
# prelec_elevation        1.810253
# prelec_gamma           0.6523251
# sc                      35.00473
# tau                 1.402454e-09
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1369.997
# k                              6
# N                            280
# bic                     2773.802
# theta                         30
# mu                    0.00230579
# p_stay              6.431507e-11
# prelec_elevation        1.810253
# prelec_gamma           0.6523251
# sc                      35.00473
# tau                 1.402454e-09
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1369.997
# k                              6
# N                            280
# bic                     2773.802
# theta                         30
# mu                    0.00230579
# p_stay              6.431507e-11
# prelec_elevation        1.810253
# prelec_gamma           0.6523251
# sc                      35.00473
# tau                 1.402454e-09
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1369.996564  6  280  2773.801866     30  0.002306
#
#          p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  6.431507e-11          1.810253      0.652325  35.004734  1.402454e-09
# frey_individual_planned_session=S14(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1370.909
# k                       6
# N                     280
# bic              2775.627
# theta                  30
# mu             0.00230579
# p_stay          0.2424953
# pow_gain        0.5702971
# sc               35.00473
# tau          1.211715e-08
# w_loss           7.302711
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1370.909
# k                       6
# N                     280
# bic              2775.627
# theta                  30
# mu             0.00230579
# p_stay          0.2424953
# pow_gain        0.5702971
# sc               35.00473
# tau          1.211715e-08
# w_loss           7.302711
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1370.909
# k                       6
# N                     280
# bic              2775.627
# theta                  30
# mu             0.00230579
# p_stay          0.2424953
# pow_gain        0.5702971
# sc               35.00473
# tau          1.211715e-08
# w_loss           7.302711
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1370.909354  6  280  2775.627446     30  0.002306
#
#      p_stay  pow_gain         sc           tau    w_loss
# 0  0.242495  0.570297  35.004734  1.211715e-08  7.302711
# frey_individual_planned_session=S15(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1372.362
# k                              6
# N                            280
# bic                     2778.533
# theta                         30
# mu                   0.004769038
# p_stay                 0.8567584
# prelec_elevation        3.250576
# prelec_gamma           0.9257006
# sc                      33.77387
# tau                 3.409044e-10
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1372.362
# k                              6
# N                            280
# bic                     2778.533
# theta                         30
# mu                   0.004769038
# p_stay                 0.8567584
# prelec_elevation        3.250576
# prelec_gamma           0.9257006
# sc                      33.77387
# tau                 3.409044e-10
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1372.362
# k                              6
# N                            280
# bic                     2778.533
# theta                         30
# mu                   0.004769038
# p_stay                 0.8567584
# prelec_elevation        3.250576
# prelec_gamma           0.9257006
# sc                      33.77387
# tau                 3.409044e-10
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1372.361982  6  280  2778.532701     30  0.004769
#
#      p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.856758          3.250576      0.925701  33.773868  3.409044e-10
# frey_individual_planned_session=S15(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh              1373.18
# k                       6
# N                     280
# bic              2780.168
# theta                  30
# mu            0.004771494
# p_stay          0.5769901
# pow_gain        0.5082756
# sc               33.77387
# tau          7.747943e-10
# w_loss           11.35172
# Name: 0, dtype: object
# 1/3
# ...
# N                            278
# bic                     2783.391
# theta                         30
# mu                  1.296343e-06
# p_stay                 0.2469942
# prelec_elevation        1.423384
# prelec_gamma            1.242971
# sc                      35.86968
# tau                    0.7305082
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1374.813
# k                              6
# N                            278
# bic                     2783.391
# theta                         30
# mu                  1.296343e-06
# p_stay                 0.2469942
# prelec_elevation        1.423384
# prelec_gamma            1.242971
# sc                      35.86968
# tau                    0.7305082
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1374.813
# k                              6
# N                            278
# bic                     2783.391
# theta                         30
# mu                  1.296343e-06
# p_stay                 0.2469942
# prelec_elevation        1.423384
# prelec_gamma            1.242971
# sc                      35.86968
# tau                    0.7305082
# Name: 2, dtype: object
#    iteration success         nllh  k    N         bic  theta        mu  \
# 0          0    True  1374.812617  6  278  2783.39096     30  0.000001
#
#      p_stay  prelec_elevation  prelec_gamma         sc       tau
# 0  0.246994          1.423384      1.242971  35.869684  0.730508
# frey_individual_planned_session=S17(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration              0
# success             True
# nllh            1378.656
# k                      6
# N                    278
# bic             2791.078
# theta                 30
# mu           1.30083e-06
# p_stay         0.1146894
# pow_gain       0.6920935
# sc              35.86968
# tau            0.3432077
# w_loss          9.438367
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration              1
# success             True
# nllh            1378.656
# k                      6
# N                    278
# bic             2791.078
# theta                 30
# mu           1.30083e-06
# p_stay         0.1146894
# pow_gain       0.6920935
# sc              35.86968
# tau            0.3432077
# w_loss          9.438367
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration              2
# success             True
# nllh            1378.656
# k                      6
# N                    278
# bic             2791.078
# theta                 30
# mu           1.30083e-06
# p_stay         0.1146894
# pow_gain       0.6920935
# sc              35.86968
# tau            0.3432077
# w_loss          9.438367
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1378.656334  6  278  2791.078395     30  0.000001
#
#      p_stay  pow_gain         sc       tau    w_loss
# 0  0.114689  0.692094  35.869684  0.343208  9.438367
# frey_individual_planned_session=S18(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1352.867
# k                              6
# N                            280
# bic                     2739.542
# theta                         30
# mu                  6.242046e-05
# p_stay                0.04085503
# prelec_elevation        1.223288
# prelec_gamma            1.201633
# sc                      32.09646
# tau                     0.431349
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1352.867
# k                              6
# N                            280
# bic                     2739.542
# theta                         30
# mu                  6.242046e-05
# p_stay                0.04085503
# prelec_elevation        1.223288
# prelec_gamma            1.201633
# sc                      32.09646
# tau                     0.431349
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1352.867
# k                              6
# N                            280
# bic                     2739.542
# theta                         30
# mu                  6.242046e-05
# p_stay                0.04085503
# prelec_elevation        1.223288
# prelec_gamma            1.201633
# sc                      32.09646
# tau                     0.431349
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1352.866596  6  280  2739.541929     30  0.000062
#
#      p_stay  prelec_elevation  prelec_gamma         sc       tau
# 0  0.040855          1.223288      1.201633  32.096463  0.431349
# frey_individual_planned_session=S18(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh              1354.98
# k                       6
# N                     280
# bic              2743.769
# theta                  30
# mu           6.241127e-05
# p_stay         0.01507148
# pow_gain         0.705419
# sc               32.09646
# tau            0.05961958
# w_loss           10.82087
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh              1354.98
# k                       6
# N                     280
# bic              2743.769
# theta                  30
# mu           6.241127e-05
# p_stay         0.01507148
# pow_gain         0.705419
# sc               32.09646
# tau            0.05961958
# w_loss           10.82087
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh              1354.98
# k                       6
# N                     280
# bic              2743.769
# theta                  30
# mu           6.241127e-05
# p_stay         0.01507148
# pow_gain         0.705419
# sc               32.09646
# tau            0.05961958
# w_loss           10.82087
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1354.980249  6  280  2743.769236     30  0.000062
#
#      p_stay  pow_gain         sc      tau     w_loss
# 0  0.015071  0.705419  32.096463  0.05962  10.820873
# frey_individual_planned_session=S19(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1303.437
# k                              6
# N                            268
# bic                     2640.419
# theta                         30
# mu                     0.9943451
# p_stay                  0.738879
# prelec_elevation        1.741154
# prelec_gamma            1.115667
# sc                      32.71585
# tau                 9.846975e-11
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1303.437
# k                              6
# N                            268
# bic                     2640.419
# theta                         30
# mu                     0.9943451
# p_stay                  0.738879
# prelec_elevation        1.741154
# prelec_gamma            1.115667
# sc                      32.71585
# tau                 9.846975e-11
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1303.437
# k                              6
# N                            268
# bic                     2640.419
# theta                         30
# mu                     0.9943451
# p_stay                  0.738879
# prelec_elevation        1.741154
# prelec_gamma            1.115667
# sc                      32.71585
# tau                 9.846975e-11
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1303.436749  6  268  2640.419419     30  0.994345
#
#      p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.738879          1.741154      1.115667  32.715848  9.846975e-11
# frey_individual_planned_session=S19(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1304.596
# k                       6
# N                     268
# bic              2642.739
# theta                  30
# mu              0.9943451
# p_stay          0.6825406
# pow_gain        0.5614322
# sc               32.71585
# tau          2.436393e-10
# w_loss           10.80094
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1304.596
# k                       6
# N                     268
# bic              2642.739
# theta                  30
# mu              0.9943451
# p_stay          0.6825406
# pow_gain        0.5614322
# sc               32.71585
# tau          2.436393e-10
# w_loss           10.80094
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1304.596
# k                       6
# N                     268
# bic              2642.739
# theta                  30
# mu              0.9943451
# p_stay          0.6825406
# pow_gain        0.5614322
# sc               32.71585
# tau          2.436393e-10
# w_loss           10.80094
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1304.596415  6  268  2642.738753     30  0.994345
#
#      p_stay  pow_gain         sc           tau     w_loss
# 0  0.682541  0.561432  32.715848  2.436393e-10  10.800942
# frey_individual_planned_session=S20(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                     1271.88
# k                              6
# N                            256
# bic                      2577.03
# theta                         30
# mu                  0.0002769759
# p_stay                 0.6433356
# prelec_elevation        1.430932
# prelec_gamma            1.098149
# sc                      35.30575
# tau                     0.789874
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                     1271.88
# k                              6
# N                            256
# bic                      2577.03
# theta                         30
# mu                  0.0002769759
# p_stay                 0.6433356
# prelec_elevation        1.430932
# prelec_gamma            1.098149
# sc                      35.30575
# tau                     0.789874
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                     1271.88
# k                              6
# N                            256
# bic                      2577.03
# theta                         30
# mu                  0.0002769759
# p_stay                 0.6433356
# prelec_elevation        1.430932
# prelec_gamma            1.098149
# sc                      35.30575
# tau                     0.789874
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1271.879666  6  256  2577.030397     30  0.000277
#
#      p_stay  prelec_elevation  prelec_gamma         sc       tau
# 0  0.643336          1.430932      1.098149  35.305747  0.789874
# frey_individual_planned_session=S20(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           1272.775
# k                     6
# N                   256
# bic            2578.821
# theta                30
# mu           0.02302948
# p_stay         0.648551
# pow_gain      0.7258942
# sc             35.30334
# tau           0.6859725
# w_loss         8.763787
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           1272.775
# k                     6
# N                   256
# bic            2578.821
# theta                30
# mu           0.02302948
# p_stay         0.648551
# pow_gain      0.7258942
# sc             35.30334
# tau           0.6859725
# w_loss         8.763787
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           1272.775
# k                     6
# N                   256
# bic            2578.821
# theta                30
# mu           0.02302948
# p_stay         0.648551
# pow_gain      0.7258942
# sc             35.30334
# tau           0.6859725
# w_loss         8.763787
# Name: 2, dtype: object
#    iteration success         nllh  k    N         bic  theta        mu  \
# 0          0    True  1272.774843  6  256  2578.82075     30  0.023029
#
#      p_stay  pow_gain         sc       tau    w_loss
# 0  0.648551  0.725894  35.303336  0.685972  8.763787
# frey_individual_planned_session=S21(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                      0
# success                     True
# nllh                    1148.077
# k                              6
# N                            232
# bic                     2328.834
# theta                         30
# mu                    0.04102528
# p_stay                 0.1389272
# prelec_elevation        1.607931
# prelec_gamma           0.9568831
# sc                      34.36485
# tau                 5.612813e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                      1
# success                     True
# nllh                    1148.077
# k                              6
# N                            232
# bic                     2328.834
# theta                         30
# mu                    0.04102528
# p_stay                 0.1389272
# prelec_elevation        1.607931
# prelec_gamma           0.9568831
# sc                      34.36485
# tau                 5.612813e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                      2
# success                     True
# nllh                    1148.077
# k                              6
# N                            232
# bic                     2328.834
# theta                         30
# mu                    0.04102528
# p_stay                 0.1389272
# prelec_elevation        1.607931
# prelec_gamma           0.9568831
# sc                      34.36485
# tau                 5.612813e-07
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1148.076906  6  232  2328.834235     30  0.041025
#
#      p_stay  prelec_elevation  prelec_gamma         sc           tau
# 0  0.138927          1.607931      0.956883  34.364848  5.612813e-07
# frey_individual_planned_session=S21(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1148.639
# k                       6
# N                     232
# bic              2329.958
# theta                  30
# mu             0.04102528
# p_stay       8.609652e-07
# pow_gain        0.5286975
# sc               34.36485
# tau          4.745167e-10
# w_loss           9.115793
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1148.639
# k                       6
# N                     232
# bic              2329.958
# theta                  30
# mu             0.04102528
# p_stay       8.609652e-07
# pow_gain        0.5286975
# sc               34.36485
# tau          4.745167e-10
# w_loss           9.115793
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1148.639
# k                       6
# N                     232
# bic              2329.958
# theta                  30
# mu             0.04102528
# p_stay       8.609652e-07
# pow_gain        0.5286975
# sc               34.36485
# tau          4.745167e-10
# w_loss           9.115793
# Name: 2, dtype: object
#    iteration success         nllh  k    N          bic  theta        mu  \
# 0          0    True  1148.638633  6  232  2329.957691     30  0.041025
#
#          p_stay  pow_gain         sc           tau    w_loss
# 0  8.609652e-07  0.528698  34.364848  4.745167e-10  9.115793

# %%
sid = 110

# %%
allresults = pd.DataFrame([], columns=['sim_id', 'k', 'N', 'nllh', 'bic'])

for parset in PARSETS_GEOM:
    fitting = {p: PARS[p] for p in parset}
    b = best_result('frey_individual_planned_geom_subj=%s' % sid, FIXED, fitting, outdir=OUTDIR, nopars=True)
    if b is None:
        print 'No success'
    else:
        allresults.loc[allresults.shape[0]] = b

for parset in PARSETS_NORMAL:
    fitting = {p: PARS[p] for p in parset}
    b = best_result('frey_individual_planned_subj=%s' % sid, FIXED, fitting, outdir=OUTDIR, nopars=True)
    if b is None:
        print 'No success'
    else:
        allresults.loc[allresults.shape[0]] = b

allresults.sort('bic')
# Out:
#                                                                                                 sim_id  \
# 3                                    frey_individual_planned_subj=110(mu,p_stay,sc,tau|c=0.5,theta=30)
# 4      frey_individual_planned_subj=110(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 5                    frey_individual_planned_subj=110(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0                              frey_individual_planned_geom_subj=110(p_stay,p_stop,tau|c=0.5,theta=30)
# 1  frey_individual_planned_geom_subj=110(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,thet...
# 2              frey_individual_planned_geom_subj=110(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
#
#    k   N         nllh          bic
# 3  4  84   233.800803   485.324874
# 4  6  84   230.480376   487.545653
# 5  6  84   231.069884   488.724668
# 0  3  84  1990.051243  3993.394936
# 1  5  84  1986.719423  3995.592931
# 2  5  84  1987.319867  3996.793818
