# %%
from chase.base import *
from chase.utils import *
from chase.fit import *
from mypy.explib.frey2014 import frey2014
pd.set_option('display.max_colwidth', 100)

# %%
arr = []
for sid in frey2014.subjects():
    print sid
    data = frey2014.subject_fitdata(sid)
    for d in data:
        arr.append([sid, d['gid'], d['group'], d['data'][0,0], d['data'][0,1]])
        
    df = pd.DataFrame(arr, columns=['subject', 'problem', 'group', 'choice', 'samplesize'])
df.to_csv('frey_data.csv')

# %%
df = frey2014.load_data()

# %%
df.to_csv('/Users/markant/Dropbox/SequentialSamplingDFE/frey_trial_data.csv')

# %%
data = pd.read_csv('data/frey_data.csv', index_col=0)
problems = {gid: frey2014.get_options(gid) for gid in data.problem.unique()}
data.head(10)
# Out:
#    subject problem  group  choice  samplesize
# 0        1    S1G1      0       0          12
# 1        1    S2G1      0       1          10
# 2        1    S3G1      0       0          10
# 3        1    S4G1      0       0          10
# 4        1    S5G1      0       0          10
# 5        1    S6G1      0       1          10
# 6        1    S7G1      0       0          10
# 7        1    S8G1      0       0          12
# 8        1    S9G1      0       0          10
# 9        1   S10G1      0       0          10

# %% [markdown]
# # Fit individual subjects

# %%
# a list of possible free parameters and their ranges
# and starting point (optional)
PARS = {'theta': [1, 50],
        'p_stay': [0, 1, .5],
        'tau': [0, 1, .5],
        'prelec_gamma': [0, 5, 1.],
        'prelec_elevation': [0, 5, 1.],
        'pow_gain': [0., 20., 1.],
        'w_loss': [0., np.inf, 1.],
        'mu': [0., np.inf, 40.],
        'sc': [0., np.inf, 1.],
        'p_stop': [0, 1, .5]}

# parameters that are set to fixed values 
FIXED = {'c': 0.5,
         'theta': 30}

N_ITER = 3
OUTDIR = 'chase_fitresults_frey_individual'

# a list of different parameter combinations that will
# be fit
PARSETS_GEOM = [#['p_stop', 'p_stay', 'tau'],
                ['p_stop', 'p_stay', 'tau', 'prelec_gamma'],
                #['p_stop', 'p_stay', 'tau', 'prelec_gamma', 'prelec_elevation'],
                ['p_stop', 'p_stay', 'tau', 'pow_gain'],
                #['p_stop', 'p_stay', 'tau', 'pow_gain', 'w_loss'],
               ]

PARSETS_NORMAL = [#['mu', 'sc', 'p_stay', 'tau'],
                  ['mu', 'sc', 'p_stay', 'tau', 'prelec_gamma'],
                  #['mu', 'sc', 'p_stay', 'tau', 'prelec_gamma', 'prelec_elevation'],
                  ['mu', 'sc', 'p_stay', 'tau', 'pow_gain'],
                  #['mu', 'sc', 'p_stay', 'tau', 'pow_gain', 'w_loss'],
                  ]

# %% [markdown]
# ### Geometric

# %%
for sid in data.subject.unique():

    SIM_ID = 'frey_individual_planned_geom_subj=%s' % sid

    for parset in PARSETS_GEOM:

        fitting = {p: PARS[p] for p in parset}

        # initialize the model
        m = CHASEAlternateStoppingModel(drift='cpt',
                                        startdist='laplace',
                                        stoprule='geometric',
                                        problems=problems)

        # fit
        results = fit_mlh(m, problems, data[data.subject==sid], 
                          SIM_ID, FIXED, fitting, niter=N_ITER, outdir=OUTDIR,
                          method='Powell')

        print results.sort('nllh').head(1)
# Out:
# frey_individual_planned_geom_subj=1(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                 0
# success                True
# nllh               328.9611
# k                         4
# N                        84
# bic                675.6455
# theta                    30
# p_stay            0.9498133
# p_stop           0.09699769
# prelec_gamma              5
# tau             0.008268857
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                 1
# success                True
# nllh               328.9611
# k                         4
# N                        84
# bic                675.6455
# theta                    30
# p_stay            0.9498133
# p_stop           0.09699769
# prelec_gamma              5
# tau             0.008268857
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                 2
# success                True
# nllh               328.9611
# k                         4
# N                        84
# bic                675.6455
# theta                    30
# p_stay            0.9498133
# p_stop           0.09699769
# prelec_gamma              5
# tau             0.008268857
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  328.961108  4  84  675.645483     30  0.949813
#
#      p_stop  prelec_gamma       tau
# 0  0.096998             5  0.008269
# frey_individual_planned_geom_subj=1(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration              0
# success             True
# nllh            332.8635
# k                      4
# N                     84
# bic             683.4502
# theta                 30
# p_stay         0.6362757
# p_stop        0.09699769
# pow_gain       0.5372171
# tau          1.81347e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration              1
# success             True
# nllh            332.8635
# k                      4
# N                     84
# bic             683.4502
# theta                 30
# p_stay         0.6362757
# p_stop        0.09699769
# pow_gain       0.5372171
# tau          1.81347e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration              2
# success             True
# nllh            332.8635
# k                      4
# N                     84
# bic             683.4502
# theta                 30
# p_stay         0.6362757
# p_stop        0.09699769
# pow_gain       0.5372171
# tau          1.81347e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta    p_stay    p_stop  \
# 0          0    True  332.863481  4  84  683.45023     30  0.636276  0.096998
#
#    pow_gain           tau
# 0  0.537217  1.813470e-08
# frey_individual_planned_geom_subj=2(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                342.8504
# k                          4
# N                         80
# bic                 703.2289
# theta                     30
# p_stay             0.2937279
# p_stop            0.06808506
# prelec_gamma        1.702047
# tau             4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                342.8504
# k                          4
# N                         80
# bic                 703.2289
# theta                     30
# p_stay             0.2937279
# p_stop            0.06808506
# prelec_gamma        1.702047
# tau             4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                342.8504
# k                          4
# N                         80
# bic                 703.2289
# theta                     30
# p_stay             0.2937279
# p_stop            0.06808506
# prelec_gamma        1.702047
# tau             4.842124e-06
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta    p_stay    p_stop  \
# 0          0    True  342.85042  4  80  703.228947     30  0.293728  0.068085
#
#    prelec_gamma       tau
# 0      1.702047  0.000005
# frey_individual_planned_geom_subj=2(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             343.2487
# k                       4
# N                      80
# bic              704.0255
# theta                  30
# p_stay       8.574846e-07
# p_stop         0.06808506
# pow_gain        0.5640763
# tau          4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             343.2487
# k                       4
# N                      80
# bic              704.0255
# theta                  30
# p_stay       8.574846e-07
# p_stop         0.06808506
# pow_gain        0.5640763
# tau          4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             343.2487
# k                       4
# N                      80
# bic              704.0255
# theta                  30
# p_stay       8.574846e-07
# p_stop         0.06808506
# pow_gain        0.5640763
# tau          4.842124e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        p_stay  \
# 0          0    True  343.248696  4  80  704.025499     30  8.574846e-07
#
#      p_stop  pow_gain       tau
# 0  0.068085  0.564076  0.000005
# frey_individual_planned_geom_subj=3(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                390.6348
# k                          4
# N                         84
# bic                 798.9929
# theta                     30
# p_stay          5.357059e-06
# p_stop            0.04783506
# prelec_gamma        1.424844
# tau                0.6247571
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                390.6348
# k                          4
# N                         84
# bic                 798.9929
# theta                     30
# p_stay          5.357059e-06
# p_stop            0.04783506
# prelec_gamma        1.424844
# tau                0.6247571
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                390.6348
# k                          4
# N                         84
# bic                 798.9929
# theta                     30
# p_stay          5.357059e-06
# p_stop            0.04783506
# prelec_gamma        1.424844
# tau                0.6247571
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  390.634806  4  84  798.992879     30  0.000005
#
#      p_stop  prelec_gamma       tau
# 0  0.047835      1.424844  0.624757
# frey_individual_planned_geom_subj=3(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           391.9272
# k                     4
# N                    84
# bic            801.5778
# theta                30
# p_stay       0.01360533
# p_stop       0.04783506
# pow_gain      0.7557295
# tau           0.2282162
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           391.9272
# k                     4
# N                    84
# bic            801.5778
# theta                30
# p_stay       0.01360533
# p_stop       0.04783506
# pow_gain      0.7557295
# tau           0.2282162
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           391.9272
# k                     4
# N                    84
# bic            801.5778
# theta                30
# p_stay       0.01360533
# p_stop       0.04783506
# pow_gain      0.7557295
# tau           0.2282162
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  391.927242  4  84  801.577752     30  0.013605
#
#      p_stop  pow_gain       tau
# 0  0.047835   0.75573  0.228216
# frey_individual_planned_geom_subj=4(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                355.1822
# k                          4
# N                         84
# bic                 728.0876
# theta                     30
# p_stay          7.178344e-05
# p_stop            0.07035176
# prelec_gamma    1.490909e-12
# tau             4.574158e-09
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                355.1822
# k                          4
# N                         84
# bic                 728.0876
# theta                     30
# p_stay          7.178344e-05
# p_stop            0.07035176
# prelec_gamma    1.490909e-12
# tau             4.574158e-09
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                355.1822
# k                          4
# N                         84
# bic                 728.0876
# theta                     30
# p_stay          7.178344e-05
# p_stop            0.07035176
# prelec_gamma    1.490909e-12
# tau             4.574158e-09
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  355.182191  4  84  728.087649     30  0.000072
#
#      p_stop  prelec_gamma           tau
# 0  0.070352  1.490909e-12  4.574158e-09
# frey_individual_planned_geom_subj=4(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             352.1178
# k                       4
# N                      84
# bic              721.9589
# theta                  30
# p_stay          0.5039102
# p_stop         0.07035176
# pow_gain         5.033732
# tau          1.150588e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             352.1178
# k                       4
# N                      84
# bic              721.9589
# theta                  30
# p_stay          0.5039102
# p_stop         0.07035176
# pow_gain         5.033732
# tau          1.150588e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             352.1178
# k                       4
# N                      84
# bic              721.9589
# theta                  30
# p_stay          0.5039102
# p_stop         0.07035176
# pow_gain         5.033732
# tau          1.150588e-07
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta   p_stay    p_stop  \
# 0          0    True  352.11783  4  84  721.958928     30  0.50391  0.070352
#
#    pow_gain           tau
# 0  5.033732  1.150588e-07
# frey_individual_planned_geom_subj=5(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              395.3414
# k                        4
# N                       84
# bic               808.4061
# theta                   30
# p_stay           0.9913069
# p_stop          0.04743083
# prelec_gamma             5
# tau             0.00577436
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              395.3414
# k                        4
# N                       84
# bic               808.4061
# theta                   30
# p_stay           0.9913069
# p_stop          0.04743083
# prelec_gamma             5
# tau             0.00577436
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              395.3414
# k                        4
# N                       84
# bic               808.4061
# theta                   30
# p_stay           0.9913069
# p_stop          0.04743083
# prelec_gamma             5
# tau             0.00577436
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta    p_stay    p_stop  \
# 0          0    True  395.34143  4  84  808.406128     30  0.991307  0.047431
#
#    prelec_gamma       tau
# 0             5  0.005774
# frey_individual_planned_geom_subj=5(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration              0
# success             True
# nllh            393.8534
# k                      4
# N                     84
# bic             805.4301
# theta                 30
# p_stay         0.8057516
# p_stop        0.04743083
# pow_gain       0.2457038
# tau          3.51204e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration              1
# success             True
# nllh            393.8534
# k                      4
# N                     84
# bic             805.4301
# theta                 30
# p_stay         0.8057516
# p_stop        0.04743083
# pow_gain       0.2457038
# tau          3.51204e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration              2
# success             True
# nllh            393.8534
# k                      4
# N                     84
# bic             805.4301
# theta                 30
# p_stay         0.8057516
# p_stop        0.04743083
# pow_gain       0.2457038
# tau          3.51204e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  393.853415  4  84  805.430097     30  0.805752
#
#      p_stop  pow_gain           tau
# 0  0.047431  0.245704  3.512040e-08
# frey_individual_planned_geom_subj=6(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                 0
# success                True
# nllh               416.2501
# k                         4
# N                        84
# bic                850.2235
# theta                    30
# p_stay            0.9844097
# p_stop           0.03579038
# prelec_gamma              5
# tau             0.005163352
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                 1
# success                True
# nllh               416.2501
# k                         4
# N                        84
# bic                850.2235
# theta                    30
# p_stay            0.9844097
# p_stop           0.03579038
# prelec_gamma              5
# tau             0.005163352
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                 2
# success                True
# nllh               416.2501
# k                         4
# N                        84
# bic                850.2235
# theta                    30
# p_stay            0.9844097
# p_stop           0.03579038
# prelec_gamma              5
# tau             0.005163352
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta   p_stay   p_stop  \
# 0          0    True  416.250102  4  84  850.223471     30  0.98441  0.03579
#
#    prelec_gamma       tau
# 0             5  0.005163
# frey_individual_planned_geom_subj=6(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             417.0682
# k                       4
# N                      84
# bic              851.8596
# theta                  30
# p_stay          0.6807572
# p_stop         0.03579038
# pow_gain        0.4249737
# tau          3.466433e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             417.0682
# k                       4
# N                      84
# bic              851.8596
# theta                  30
# p_stay          0.6807572
# p_stop         0.03579038
# pow_gain        0.4249737
# tau          3.466433e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             417.0682
# k                       4
# N                      84
# bic              851.8596
# theta                  30
# p_stay          0.6807572
# p_stop         0.03579038
# pow_gain        0.4249737
# tau          3.466433e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay   p_stop  \
# 0          0    True  417.068184  4  84  851.859635     30  0.680757  0.03579
#
#    pow_gain           tau
# 0  0.424974  3.466433e-08
# frey_individual_planned_geom_subj=7(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                 0
# success                True
# nllh                 484.56
# k                         4
# N                        83
# bic                986.7954
# theta                    30
# p_stay            0.4150528
# p_stop           0.01506351
# prelec_gamma        0.64807
# tau             6.13311e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                 1
# success                True
# nllh                 484.56
# k                         4
# N                        83
# bic                986.7954
# theta                    30
# p_stay            0.4150528
# p_stop           0.01506351
# prelec_gamma        0.64807
# tau             6.13311e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                 2
# success                True
# nllh                 484.56
# k                         4
# N                        83
# bic                986.7954
# theta                    30
# p_stay            0.4150528
# p_stop           0.01506351
# prelec_gamma        0.64807
# tau             6.13311e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  484.560042  4  83  986.795447     30  0.415053
#
#      p_stop  prelec_gamma           tau
# 0  0.015064       0.64807  6.133110e-08
# frey_individual_planned_geom_subj=7(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           486.9629
# k                     4
# N                    83
# bic            991.6011
# theta                30
# p_stay          0.64231
# p_stop       0.01507961
# pow_gain       1.116404
# tau           0.7074091
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           486.9629
# k                     4
# N                    83
# bic            991.6011
# theta                30
# p_stay          0.64231
# p_stop       0.01507961
# pow_gain       1.116404
# tau           0.7074091
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           486.9629
# k                     4
# N                    83
# bic            991.6011
# theta                30
# p_stay          0.64231
# p_stop       0.01507961
# pow_gain       1.116404
# tau           0.7074091
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta   p_stay   p_stop  \
# 0          0    True  486.962878  4  83  991.601118     30  0.64231  0.01508
#
#    pow_gain       tau
# 0  1.116404  0.707409
# frey_individual_planned_geom_subj=8(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              459.5108
# k                        4
# N                       83
# bic                936.697
# theta                   30
# p_stay           0.4068424
# p_stop          0.01946265
# prelec_gamma      1.546324
# tau              0.6465712
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              459.5108
# k                        4
# N                       83
# bic                936.697
# theta                   30
# p_stay           0.4068424
# p_stop          0.01946265
# prelec_gamma      1.546324
# tau              0.6465712
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              459.5108
# k                        4
# N                       83
# bic                936.697
# theta                   30
# p_stay           0.4068424
# p_stop          0.01946265
# prelec_gamma      1.546324
# tau              0.6465712
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  459.510808  4  83  936.696979     30  0.406842
#
#      p_stop  prelec_gamma       tau
# 0  0.019463      1.546324  0.646571
# frey_individual_planned_geom_subj=8(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           458.8918
# k                     4
# N                    83
# bic            935.4589
# theta                30
# p_stay        0.3238843
# p_stop       0.01946265
# pow_gain      0.6010837
# tau           0.1385744
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           458.8918
# k                     4
# N                    83
# bic            935.4589
# theta                30
# p_stay        0.3238843
# p_stop       0.01946265
# pow_gain      0.6010837
# tau           0.1385744
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           458.8918
# k                     4
# N                    83
# bic            935.4589
# theta                30
# p_stay        0.3238843
# p_stop       0.01946265
# pow_gain      0.6010837
# tau           0.1385744
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  458.891761  4  83  935.458884     30  0.323884
#
#      p_stop  pow_gain       tau
# 0  0.019463  0.601084  0.138574
# frey_individual_planned_geom_subj=9(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              367.4565
# k                        4
# N                       80
# bic               752.4411
# theta                   30
# p_stay            0.955353
# p_stop          0.05249213
# prelec_gamma      2.843832
# tau              0.4905046
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              367.4565
# k                        4
# N                       80
# bic               752.4411
# theta                   30
# p_stay            0.955353
# p_stop          0.05249213
# prelec_gamma      2.843832
# tau              0.4905046
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              367.4565
# k                        4
# N                       80
# bic               752.4411
# theta                   30
# p_stay            0.955353
# p_stop          0.05249213
# prelec_gamma      2.843832
# tau              0.4905046
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  367.456483  4  80  752.441072     30  0.955353
#
#      p_stop  prelec_gamma       tau
# 0  0.052492      2.843832  0.490505
# frey_individual_planned_geom_subj=9(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh             368.87
# k                     4
# N                    80
# bic            755.2681
# theta                30
# p_stay        0.9452861
# p_stop       0.05249213
# pow_gain      0.6686541
# tau          0.07318591
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh             368.87
# k                     4
# N                    80
# bic            755.2681
# theta                30
# p_stay        0.9452861
# p_stop       0.05249213
# pow_gain      0.6686541
# tau          0.07318591
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh             368.87
# k                     4
# N                    80
# bic            755.2681
# theta                30
# p_stay        0.9452861
# p_stop       0.05249213
# pow_gain      0.6686541
# tau          0.07318591
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  368.870004  4  80  755.268115     30  0.945286
#
#      p_stop  pow_gain       tau
# 0  0.052492  0.668654  0.073186
# frey_individual_planned_geom_subj=12(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                449.2995
# k                          4
# N                         83
# bic                 916.2745
# theta                     30
# p_stay          9.696956e-08
# p_stop            0.01985642
# prelec_gamma        1.698877
# tau                0.7257259
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                449.2995
# k                          4
# N                         83
# bic                 916.2745
# theta                     30
# p_stay          9.696956e-08
# p_stop            0.01985642
# prelec_gamma        1.698877
# tau                0.7257259
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                449.2995
# k                          4
# N                         83
# bic                 916.2745
# theta                     30
# p_stay          9.696956e-08
# p_stop            0.01985642
# prelec_gamma        1.698877
# tau                0.7257259
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        p_stay  \
# 0          0    True  449.299547  4  83  916.274457     30  9.696956e-08
#
#      p_stop  prelec_gamma       tau
# 0  0.019856      1.698877  0.725726
# frey_individual_planned_geom_subj=12(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             457.3516
# k                       4
# N                      83
# bic              932.3786
# theta                  30
# p_stay       0.0009514367
# p_stop         0.01985642
# pow_gain         0.744259
# tau             0.1502119
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             457.3516
# k                       4
# N                      83
# bic              932.3786
# theta                  30
# p_stay       0.0009514367
# p_stop         0.01985642
# pow_gain         0.744259
# tau             0.1502119
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             457.3516
# k                       4
# N                      83
# bic              932.3786
# theta                  30
# p_stay       0.0009514367
# p_stop         0.01985642
# pow_gain         0.744259
# tau             0.1502119
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  457.351636  4  83  932.378634     30  0.000951
#
#      p_stop  pow_gain       tau
# 0  0.019856  0.744259  0.150212
# frey_individual_planned_geom_subj=13(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                 0
# success                True
# nllh                332.535
# k                         4
# N                        80
# bic                682.5981
# theta                    30
# p_stay            0.9873072
# p_stop           0.08088978
# prelec_gamma              5
# tau             0.006139814
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                 1
# success                True
# nllh                332.535
# k                         4
# N                        80
# bic                682.5981
# theta                    30
# p_stay            0.9873072
# p_stop           0.08088978
# prelec_gamma              5
# tau             0.006139814
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                 2
# success                True
# nllh                332.535
# k                         4
# N                        80
# bic                682.5981
# theta                    30
# p_stay            0.9873072
# p_stop           0.08088978
# prelec_gamma              5
# tau             0.006139814
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay   p_stop  \
# 0          0    True  332.534985  4  80  682.598076     30  0.987307  0.08089
#
#    prelec_gamma      tau
# 0             5  0.00614
# frey_individual_planned_geom_subj=13(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             331.0764
# k                       4
# N                      80
# bic              679.6809
# theta                  30
# p_stay          0.6542233
# p_stop         0.08088978
# pow_gain         0.300472
# tau          3.466433e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             331.0764
# k                       4
# N                      80
# bic              679.6809
# theta                  30
# p_stay          0.6542233
# p_stop         0.08088978
# pow_gain         0.300472
# tau          3.466433e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             331.0764
# k                       4
# N                      80
# bic              679.6809
# theta                  30
# p_stay          0.6542233
# p_stop         0.08088978
# pow_gain         0.300472
# tau          3.466433e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay   p_stop  \
# 0          0    True  331.076378  4  80  679.680862     30  0.654223  0.08089
#
#    pow_gain           tau
# 0  0.300472  3.466433e-08
# frey_individual_planned_geom_subj=15(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                 0
# success                True
# nllh               334.6211
# k                         4
# N                        84
# bic                686.9655
# theta                    30
# p_stay          4.27862e-05
# p_stop           0.09302031
# prelec_gamma       1.600168
# tau               0.7325529
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                 1
# success                True
# nllh               334.6211
# k                         4
# N                        84
# bic                686.9655
# theta                    30
# p_stay          4.27862e-05
# p_stop           0.09302031
# prelec_gamma       1.600168
# tau               0.7325529
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                 2
# success                True
# nllh               334.6211
# k                         4
# N                        84
# bic                686.9655
# theta                    30
# p_stay          4.27862e-05
# p_stop           0.09302031
# prelec_gamma       1.600168
# tau               0.7325529
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay   p_stop  \
# 0          0    True  334.621114  4  84  686.965496     30  0.000043  0.09302
#
#    prelec_gamma       tau
# 0      1.600168  0.732553
# frey_individual_planned_geom_subj=15(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             333.6757
# k                       4
# N                      84
# bic              685.0748
# theta                  30
# p_stay       2.072581e-05
# p_stop         0.09302031
# pow_gain        0.5047506
# tau             0.4690387
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             333.6757
# k                       4
# N                      84
# bic              685.0748
# theta                  30
# p_stay       2.072581e-05
# p_stop         0.09302031
# pow_gain        0.5047506
# tau             0.4690387
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             333.6757
# k                       4
# N                      84
# bic              685.0748
# theta                  30
# p_stay       2.072581e-05
# p_stop         0.09302031
# pow_gain        0.5047506
# tau             0.4690387
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta    p_stay   p_stop  \
# 0          0    True  333.67575  4  84  685.074767     30  0.000021  0.09302
#
#    pow_gain       tau
# 0  0.504751  0.469039
# frey_individual_planned_geom_subj=16(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              437.3741
# k                        4
# N                       84
# bic               892.4714
# theta                   30
# p_stay          0.07614517
# p_stop          0.02717345
# prelec_gamma      1.474875
# tau               0.719782
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              437.3741
# k                        4
# N                       84
# bic               892.4714
# theta                   30
# p_stay          0.07614517
# p_stop          0.02717345
# prelec_gamma      1.474875
# tau               0.719782
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              437.3741
# k                        4
# N                       84
# bic               892.4714
# theta                   30
# p_stay          0.07614517
# p_stop          0.02717345
# prelec_gamma      1.474875
# tau               0.719782
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  437.374074  4  84  892.471416     30  0.076145
#
#      p_stop  prelec_gamma       tau
# 0  0.027173      1.474875  0.719782
# frey_individual_planned_geom_subj=16(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             437.0281
# k                       4
# N                      84
# bic              891.7794
# theta                  30
# p_stay          0.0281062
# p_stop         0.02717345
# pow_gain         0.646858
# tau          0.0001948256
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             437.0281
# k                       4
# N                      84
# bic              891.7794
# theta                  30
# p_stay          0.0281062
# p_stop         0.02717345
# pow_gain         0.646858
# tau          0.0001948256
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             437.0281
# k                       4
# N                      84
# bic              891.7794
# theta                  30
# p_stay          0.0281062
# p_stop         0.02717345
# pow_gain         0.646858
# tau          0.0001948256
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  437.028053  4  84  891.779373     30  0.028106
#
#      p_stop  pow_gain       tau
# 0  0.027173  0.646858  0.000195
# frey_individual_planned_geom_subj=17(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                 385.579
# k                          4
# N                         84
# bic                 788.8813
# theta                     30
# p_stay          8.172421e-05
# p_stop            0.05197157
# prelec_gamma        1.322698
# tau                0.7193813
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                 385.579
# k                          4
# N                         84
# bic                 788.8813
# theta                     30
# p_stay          8.172421e-05
# p_stop            0.05197157
# prelec_gamma        1.322698
# tau                0.7193813
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                 385.579
# k                          4
# N                         84
# bic                 788.8813
# theta                     30
# p_stay          8.172421e-05
# p_stop            0.05197157
# prelec_gamma        1.322698
# tau                0.7193813
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  385.579004  4  84  788.881274     30  0.000082
#
#      p_stop  prelec_gamma       tau
# 0  0.051972      1.322698  0.719381
# frey_individual_planned_geom_subj=17(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             384.3625
# k                       4
# N                      84
# bic              786.4482
# theta                  30
# p_stay       1.632491e-05
# p_stop         0.05197157
# pow_gain        0.6246406
# tau             0.5305524
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             384.3625
# k                       4
# N                      84
# bic              786.4482
# theta                  30
# p_stay       1.632491e-05
# p_stop         0.05197157
# pow_gain        0.6246406
# tau             0.5305524
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             384.3625
# k                       4
# N                      84
# bic              786.4482
# theta                  30
# p_stay       1.632491e-05
# p_stop         0.05197157
# pow_gain        0.6246406
# tau             0.5305524
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta    p_stay    p_stop  \
# 0          0    True  384.362452  4  84  786.44817     30  0.000016  0.051972
#
#    pow_gain       tau
# 0  0.624641  0.530552
# frey_individual_planned_geom_subj=18(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                 419.662
# k                          4
# N                         84
# bic                 857.0473
# theta                     30
# p_stay             0.5293182
# p_stop            0.03395311
# prelec_gamma       0.1617462
# tau             4.120725e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                 419.662
# k                          4
# N                         84
# bic                 857.0473
# theta                     30
# p_stay             0.5293182
# p_stop            0.03395311
# prelec_gamma       0.1617462
# tau             4.120725e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                 419.662
# k                          4
# N                         84
# bic                 857.0473
# theta                     30
# p_stay             0.5293182
# p_stop            0.03395311
# prelec_gamma       0.1617462
# tau             4.120725e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  419.662023  4  84  857.047312     30  0.529318
#
#      p_stop  prelec_gamma           tau
# 0  0.033953      0.161746  4.120725e-07
# frey_individual_planned_geom_subj=18(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             420.6231
# k                       4
# N                      84
# bic              858.9695
# theta                  30
# p_stay          0.8848852
# p_stop         0.03395379
# pow_gain          4.25534
# tau          4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             420.6231
# k                       4
# N                      84
# bic              858.9695
# theta                  30
# p_stay          0.8848852
# p_stop         0.03395379
# pow_gain          4.25534
# tau          4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             420.6231
# k                       4
# N                      84
# bic              858.9695
# theta                  30
# p_stay          0.8848852
# p_stop         0.03395379
# pow_gain          4.25534
# tau          4.842124e-06
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta    p_stay    p_stop  \
# 0          0    True  420.62314  4  84  858.969547     30  0.884885  0.033954
#
#    pow_gain       tau
# 0   4.25534  0.000005
# frey_individual_planned_geom_subj=20(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                334.3014
# k                          4
# N                         84
# bic                 686.3261
# theta                     30
# p_stay          6.685646e-05
# p_stop            0.09407127
# prelec_gamma       0.4988728
# tau             4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                334.3014
# k                          4
# N                         84
# bic                 686.3261
# theta                     30
# p_stay          6.685646e-05
# p_stop            0.09407127
# prelec_gamma       0.4988728
# tau             4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                334.3014
# k                          4
# N                         84
# bic                 686.3261
# theta                     30
# p_stay          6.685646e-05
# p_stop            0.09407127
# prelec_gamma       0.4988728
# tau             4.842124e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  334.301417  4  84  686.326102     30  0.000067
#
#      p_stop  prelec_gamma       tau
# 0  0.094071      0.498873  0.000005
# frey_individual_planned_geom_subj=20(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             334.5191
# k                       4
# N                      84
# bic              686.7615
# theta                  30
# p_stay         0.05932927
# p_stop         0.09407127
# pow_gain         1.484065
# tau          4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             334.5191
# k                       4
# N                      84
# bic              686.7615
# theta                  30
# p_stay         0.05932927
# p_stop         0.09407127
# pow_gain         1.484065
# tau          4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             334.5191
# k                       4
# N                      84
# bic              686.7615
# theta                  30
# p_stay         0.05932927
# p_stop         0.09407127
# pow_gain         1.484065
# tau          4.842124e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  334.519102  4  84  686.761472     30  0.059329
#
#      p_stop  pow_gain       tau
# 0  0.094071  1.484065  0.000005
# frey_individual_planned_geom_subj=21(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              401.4265
# k                        4
# N                       84
# bic               820.5763
# theta                   30
# p_stay           0.7485965
# p_stop          0.04398625
# prelec_gamma     0.3896921
# tau              0.2526002
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              401.4265
# k                        4
# N                       84
# bic               820.5763
# theta                   30
# p_stay           0.7485965
# p_stop          0.04398625
# prelec_gamma     0.3896921
# tau              0.2526002
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              401.4265
# k                        4
# N                       84
# bic               820.5763
# theta                   30
# p_stay           0.7485965
# p_stop          0.04398625
# prelec_gamma     0.3896921
# tau              0.2526002
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  401.426513  4  84  820.576294     30  0.748596
#
#      p_stop  prelec_gamma     tau
# 0  0.043986      0.389692  0.2526
# frey_individual_planned_geom_subj=21(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           402.2892
# k                     4
# N                    84
# bic            822.3016
# theta                30
# p_stay        0.7989835
# p_stop       0.04398625
# pow_gain       1.736385
# tau           0.6866201
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           402.2892
# k                     4
# N                    84
# bic            822.3016
# theta                30
# p_stay        0.7989835
# p_stop       0.04398625
# pow_gain       1.736385
# tau           0.6866201
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           402.2892
# k                     4
# N                    84
# bic            822.3016
# theta                30
# p_stay        0.7989835
# p_stop       0.04398625
# pow_gain       1.736385
# tau           0.6866201
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  402.289163  4  84  822.301593     30  0.798984
#
#      p_stop  pow_gain      tau
# 0  0.043986  1.736385  0.68662
# frey_individual_planned_geom_subj=22(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                406.8565
# k                          4
# N                         84
# bic                 831.4363
# theta                     30
# p_stay             0.4780489
# p_stop            0.04156281
# prelec_gamma       0.9294112
# tau             9.184398e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                406.8565
# k                          4
# N                         84
# bic                 831.4363
# theta                     30
# p_stay             0.4780489
# p_stop            0.04156281
# prelec_gamma       0.9294112
# tau             9.184398e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                406.8565
# k                          4
# N                         84
# bic                 831.4363
# theta                     30
# p_stay             0.4780489
# p_stop            0.04156281
# prelec_gamma       0.9294112
# tau             9.184398e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  406.856541  4  84  831.436348     30  0.478049
#
#      p_stop  prelec_gamma       tau
# 0  0.041563      0.929411  0.000009
# frey_individual_planned_geom_subj=22(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             406.7227
# k                       4
# N                      84
# bic              831.1687
# theta                  30
# p_stay          0.4946345
# p_stop         0.04156281
# pow_gain          1.13727
# tau          1.514634e-05
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             406.7227
# k                       4
# N                      84
# bic              831.1687
# theta                  30
# p_stay          0.4946345
# p_stop         0.04156281
# pow_gain          1.13727
# tau          1.514634e-05
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             406.7227
# k                       4
# N                      84
# bic              831.1687
# theta                  30
# p_stay          0.4946345
# p_stop         0.04156281
# pow_gain          1.13727
# tau          1.514634e-05
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  406.722723  4  84  831.168712     30  0.494634
#
#      p_stop  pow_gain       tau
# 0  0.041563   1.13727  0.000015
# frey_individual_planned_geom_subj=23(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                362.1945
# k                          4
# N                         84
# bic                 742.1122
# theta                     30
# p_stay          1.526317e-05
# p_stop            0.06650824
# prelec_gamma        1.645683
# tau                0.6728382
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                362.1945
# k                          4
# N                         84
# bic                 742.1122
# theta                     30
# p_stay          1.526317e-05
# p_stop            0.06650824
# prelec_gamma        1.645683
# tau                0.6728382
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                362.1945
# k                          4
# N                         84
# bic                 742.1122
# theta                     30
# p_stay          1.526317e-05
# p_stop            0.06650824
# prelec_gamma        1.645683
# tau                0.6728382
# Name: 2, dtype: object
# ...
# tau          1.606821e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  405.660204  4  80  828.848515     30  0.000035
#
#      p_stop  pow_gain       tau
# 0  0.030673  0.781012  0.000002
# frey_individual_planned_geom_subj=132(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                428.1712
# k                          4
# N                         84
# bic                 874.0657
# theta                     30
# p_stay          2.769373e-07
# p_stop            0.02914818
# prelec_gamma        1.607132
# tau                0.7146982
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                428.1712
# k                          4
# N                         84
# bic                 874.0657
# theta                     30
# p_stay          2.769373e-07
# p_stop            0.02914818
# prelec_gamma        1.607132
# tau                0.7146982
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                428.1712
# k                          4
# N                         84
# bic                 874.0657
# theta                     30
# p_stay          2.769373e-07
# p_stop            0.02914818
# prelec_gamma        1.607132
# tau                0.7146982
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta        p_stay  \
# 0          0    True  428.17122  4  84  874.065706     30  2.769373e-07
#
#      p_stop  prelec_gamma       tau
# 0  0.029148      1.607132  0.714698
# frey_individual_planned_geom_subj=132(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             423.5687
# k                       4
# N                      84
# bic              864.8606
# theta                  30
# p_stay       5.465338e-07
# p_stop         0.02914818
# pow_gain         0.463247
# tau          1.428143e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             423.5687
# k                       4
# N                      84
# bic              864.8606
# theta                  30
# p_stay       5.465338e-07
# p_stop         0.02914818
# pow_gain         0.463247
# tau          1.428143e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             423.5687
# k                       4
# N                      84
# bic              864.8606
# theta                  30
# p_stay       5.465338e-07
# p_stop         0.02914818
# pow_gain         0.463247
# tau          1.428143e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N       bic  theta        p_stay  \
# 0          0    True  423.568666  4  84  864.8606     30  5.465338e-07
#
#      p_stop  pow_gain           tau
# 0  0.029148  0.463247  1.428143e-07
# frey_individual_planned_geom_subj=133(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                338.7544
# k                          4
# N                         75
# bic                 694.7787
# theta                     30
# p_stay             0.7869302
# p_stop            0.05673223
# prelec_gamma       0.1400968
# tau             2.486135e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                338.7544
# k                          4
# N                         75
# bic                 694.7787
# theta                     30
# p_stay             0.7869302
# p_stop            0.05673223
# prelec_gamma       0.1400968
# tau             2.486135e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                338.7544
# k                          4
# N                         75
# bic                 694.7787
# theta                     30
# p_stay             0.7869302
# p_stop            0.05673223
# prelec_gamma       0.1400968
# tau             2.486135e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta   p_stay    p_stop  \
# 0          0    True  338.754355  4  75  694.778663     30  0.78693  0.056732
#
#    prelec_gamma           tau
# 0      0.140097  2.486135e-07
# frey_individual_planned_geom_subj=133(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             338.8593
# k                       4
# N                      75
# bic              694.9886
# theta                  30
# p_stay          0.9161699
# p_stop         0.05673223
# pow_gain         2.978631
# tau          3.466433e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             338.8593
# k                       4
# N                      75
# bic              694.9886
# theta                  30
# p_stay          0.9161699
# p_stop         0.05673223
# pow_gain         2.978631
# tau          3.466433e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             338.8593
# k                       4
# N                      75
# bic              694.9886
# theta                  30
# p_stay          0.9161699
# p_stop         0.05673223
# pow_gain         2.978631
# tau          3.466433e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta   p_stay    p_stop  \
# 0          0    True  338.859301  4  75  694.988555     30  0.91617  0.056732
#
#    pow_gain           tau
# 0  2.978631  3.466433e-08
# frey_individual_planned_geom_subj=134(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                370.5398
# k                          4
# N                         84
# bic                 758.8028
# theta                     30
# p_stay          5.711743e-07
# p_stop            0.05995873
# prelec_gamma        1.565106
# tau                 0.611685
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                370.5398
# k                          4
# N                         84
# bic                 758.8028
# theta                     30
# p_stay          5.711743e-07
# p_stop            0.05995873
# prelec_gamma        1.565106
# tau                 0.611685
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                370.5398
# k                          4
# N                         84
# bic                 758.8028
# theta                     30
# p_stay          5.711743e-07
# p_stop            0.05995873
# prelec_gamma        1.565106
# tau                 0.611685
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        p_stay  \
# 0          0    True  370.539785  4  84  758.802838     30  5.711743e-07
#
#      p_stop  prelec_gamma       tau
# 0  0.059959      1.565106  0.611685
# frey_individual_planned_geom_subj=134(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             369.3417
# k                       4
# N                      84
# bic              756.4067
# theta                  30
# p_stay       9.729756e-05
# p_stop         0.05995873
# pow_gain        0.4948221
# tau          2.168798e-05
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             369.3417
# k                       4
# N                      84
# bic              756.4067
# theta                  30
# p_stay       9.729756e-05
# p_stop         0.05995873
# pow_gain        0.4948221
# tau          2.168798e-05
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             369.3417
# k                       4
# N                      84
# bic              756.4067
# theta                  30
# p_stay       9.729756e-05
# p_stop         0.05995873
# pow_gain        0.4948221
# tau          2.168798e-05
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta    p_stay    p_stop  \
# 0          0    True  369.341701  4  84  756.40667     30  0.000097  0.059959
#
#    pow_gain       tau
# 0  0.494822  0.000022
# frey_individual_planned_geom_subj=135(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              1976.148
# k                        4
# N                       84
# bic                3970.02
# theta                   30
# p_stay          0.02057645
# p_stop                 0.5
# prelec_gamma      1.500862
# tau              0.4754494
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              1976.148
# k                        4
# N                       84
# bic                3970.02
# theta                   30
# p_stay          0.02057645
# p_stop                 0.5
# prelec_gamma      1.500862
# tau              0.4754494
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              1976.148
# k                        4
# N                       84
# bic                3970.02
# theta                   30
# p_stay          0.02057645
# p_stop                 0.5
# prelec_gamma      1.500862
# tau              0.4754494
# Name: 2, dtype: object
#    iteration success         nllh  k   N          bic  theta    p_stay  \
# 0          0    True  1976.148408  4  84  3970.020083     30  0.020576
#
#    p_stop  prelec_gamma       tau
# 0     0.5      1.500862  0.475449
# frey_individual_planned_geom_subj=135(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             1982.024
# k                       4
# N                      84
# bic              3981.771
# theta                  30
# p_stay       3.505433e-06
# p_stop                0.5
# pow_gain        0.7619056
# tau          0.0001006624
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             1982.024
# k                       4
# N                      84
# bic              3981.771
# theta                  30
# p_stay       3.505433e-06
# p_stop                0.5
# pow_gain        0.7619056
# tau          0.0001006624
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             1982.024
# k                       4
# N                      84
# bic              3981.771
# theta                  30
# p_stay       3.505433e-06
# p_stop                0.5
# pow_gain        0.7619056
# tau          0.0001006624
# Name: 2, dtype: object
#    iteration success         nllh  k   N          bic  theta    p_stay  \
# 0          0    True  1982.023755  4  84  3981.770778     30  0.000004
#
#    p_stop  pow_gain       tau
# 0     0.5  0.761906  0.000101
# frey_individual_planned_geom_subj=136(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              387.0019
# k                        4
# N                       80
# bic               791.5318
# theta                   30
# p_stay           0.1478812
# p_stop          0.03810803
# prelec_gamma      1.686841
# tau               0.344771
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              387.0019
# k                        4
# N                       80
# bic               791.5318
# theta                   30
# p_stay           0.1478812
# p_stop          0.03810803
# prelec_gamma      1.686841
# tau               0.344771
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              387.0019
# k                        4
# N                       80
# bic               791.5318
# theta                   30
# p_stay           0.1478812
# p_stop          0.03810803
# prelec_gamma      1.686841
# tau               0.344771
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  387.001868  4  80  791.531843     30  0.147881
#
#      p_stop  prelec_gamma       tau
# 0  0.038108      1.686841  0.344771
# frey_individual_planned_geom_subj=136(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           389.2411
# k                     4
# N                    80
# bic            796.0103
# theta                30
# p_stay       0.02002116
# p_stop       0.03810803
# pow_gain      0.6261289
# tau            0.112675
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           389.2411
# k                     4
# N                    80
# bic            796.0103
# theta                30
# p_stay       0.02002116
# p_stop       0.03810803
# pow_gain      0.6261289
# tau            0.112675
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           389.2411
# k                     4
# N                    80
# bic            796.0103
# theta                30
# p_stay       0.02002116
# p_stop       0.03810803
# pow_gain      0.6261289
# tau            0.112675
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta    p_stay    p_stop  \
# 0          0    True  389.24108  4  80  796.010267     30  0.020021  0.038108
#
#    pow_gain       tau
# 0  0.626129  0.112675
# frey_individual_planned_geom_subj=137(p_stay,p_stop,prelec_gamma,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                 367.239
# k                          4
# N                         84
# bic                 752.2012
# theta                     30
# p_stay          8.370805e-06
# p_stop             0.0629237
# prelec_gamma        1.588552
# tau                0.6995883
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                 367.239
# k                          4
# N                         84
# bic                 752.2012
# theta                     30
# p_stay          8.370805e-06
# p_stop             0.0629237
# prelec_gamma        1.588552
# tau                0.6995883
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                 367.239
# k                          4
# N                         84
# bic                 752.2012
# theta                     30
# p_stay          8.370805e-06
# p_stop             0.0629237
# prelec_gamma        1.588552
# tau                0.6995883
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  367.238968  4  84  752.201202     30  0.000008
#
#      p_stop  prelec_gamma       tau
# 0  0.062924      1.588552  0.699588
# frey_individual_planned_geom_subj=137(p_stay,p_stop,pow_gain,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             366.3971
# k                       4
# N                      84
# bic              750.5174
# theta                  30
# p_stay       5.201945e-05
# p_stop          0.0629237
# pow_gain        0.5464106
# tau          4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             366.3971
# k                       4
# N                      84
# bic              750.5174
# theta                  30
# p_stay       5.201945e-05
# p_stop          0.0629237
# pow_gain        0.5464106
# tau          4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             366.3971
# k                       4
# N                      84
# bic              750.5174
# theta                  30
# p_stay       5.201945e-05
# p_stop          0.0629237
# pow_gain        0.5464106
# tau          4.842124e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta    p_stay  \
# 0          0    True  366.397055  4  84  750.517377     30  0.000052
#
#      p_stop  pow_gain       tau
# 0  0.062924  0.546411  0.000005

# %% [markdown]
# ### Truncated normal

# %%
data.subject.unique()[47:]
# Out:
# array([115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127,
#        128, 129, 130, 131, 132, 133, 134, 135, 136, 137])

# %%
for sid in data.subject.unique()[47:]:
#for sid in [12]:

    SIM_ID = 'frey_individual_planned_subj=%s' % sid

    for parset in PARSETS_NORMAL:

        fitting = {p: PARS[p] for p in parset}
        fitting['mu'][2] = data[data.subject==sid].samplesize.mean()
        
        # initialize the model
        m = CHASEAlternateStoppingModel(drift='cpt',
                                        startdist='laplace',
                                        stoprule='truncatednormal',
                                        problems=problems)

        # fit
        results = fit_mlh(m, problems, data[data.subject==sid], 
                          SIM_ID, FIXED, fitting, niter=N_ITER, outdir=OUTDIR,
                          method='Powell')

        print results.sort('nllh').head(1)
# Out:
# frey_individual_planned_subj=115(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              392.0574
# k                        5
# N                       84
# bic               806.2689
# theta                   30
# mu                14.70095
# p_stay            0.700347
# prelec_gamma     0.1668139
# sc                19.87299
# tau             0.06950983
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              392.0574
# k                        5
# N                       84
# bic               806.2689
# theta                   30
# mu                14.70095
# p_stay            0.700347
# prelec_gamma     0.1668139
# sc                19.87299
# tau             0.06950983
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              392.0574
# k                        5
# N                       84
# bic               806.2689
# theta                   30
# mu                14.70095
# p_stay            0.700347
# prelec_gamma     0.1668139
# sc                19.87299
# tau             0.06950983
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  392.057405  5  84  806.268895     30  14.700946
#
#      p_stay  prelec_gamma         sc      tau
# 0  0.700347      0.166814  19.872994  0.06951
# frey_individual_planned_subj=115(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration            0
# success           True
# nllh          394.0093
# k                    5
# N                   84
# bic           810.1726
# theta               30
# mu            15.53681
# p_stay       0.9718359
# pow_gain      19.99902
# sc            19.48159
# tau          0.3160829
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration            1
# success           True
# nllh          394.0093
# k                    5
# N                   84
# bic           810.1726
# theta               30
# mu            15.53681
# p_stay       0.9718359
# pow_gain      19.99902
# sc            19.48159
# tau          0.3160829
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration            2
# success           True
# nllh          394.0093
# k                    5
# N                   84
# bic           810.1726
# theta               30
# mu            15.53681
# p_stay       0.9718359
# pow_gain      19.99902
# sc            19.48159
# tau          0.3160829
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta         mu  \
# 0          0    True  394.009283  5  84  810.17265     30  15.536812
#
#      p_stay   pow_gain         sc       tau
# 0  0.971836  19.999021  19.481594  0.316083
# frey_individual_planned_subj=116(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                307.6108
# k                          5
# N                         84
# bic                 637.3757
# theta                     30
# mu              0.0001034909
# p_stay             0.7072466
# prelec_gamma      0.07344532
# sc                  9.485555
# tau                 0.487701
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                307.6108
# k                          5
# N                         84
# bic                 637.3757
# theta                     30
# mu              0.0001034909
# p_stay             0.7072466
# prelec_gamma      0.07344532
# sc                  9.485555
# tau                 0.487701
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                307.6108
# k                          5
# N                         84
# bic                 637.3757
# theta                     30
# mu              0.0001034909
# p_stay             0.7072466
# prelec_gamma      0.07344532
# sc                  9.485555
# tau                 0.487701
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  307.610805  5  84  637.375694     30  0.000103
#
#      p_stay  prelec_gamma        sc       tau
# 0  0.707247      0.073445  9.485555  0.487701
# frey_individual_planned_subj=116(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh              307.831
# k                       5
# N                      84
# bic               637.816
# theta                  30
# mu           0.0001034909
# p_stay          0.9473916
# pow_gain               20
# sc               9.485555
# tau             0.2327628
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh              307.831
# k                       5
# N                      84
# bic               637.816
# theta                  30
# mu           0.0001034909
# p_stay          0.9473916
# pow_gain               20
# sc               9.485555
# tau             0.2327628
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh              307.831
# k                       5
# N                      84
# bic               637.816
# theta                  30
# mu           0.0001034909
# p_stay          0.9473916
# pow_gain               20
# sc               9.485555
# tau             0.2327628
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  307.830977  5  84  637.816038     30  0.000103
#
#      p_stay  pow_gain        sc       tau
# 0  0.947392        20  9.485555  0.232763
# frey_individual_planned_subj=117(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             360.1826
# k                       5
# N                      80
# bic              742.2752
# theta                  30
# mu               32.74458
# p_stay          0.2442594
# prelec_gamma      1.00882
# sc               11.19498
# tau             0.7265317
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             360.1826
# k                       5
# N                      80
# bic              742.2752
# theta                  30
# mu               32.74458
# p_stay          0.2442594
# prelec_gamma      1.00882
# sc               11.19498
# tau             0.7265317
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             360.1826
# k                       5
# N                      80
# bic              742.2752
# theta                  30
# mu               32.74458
# p_stay          0.2442594
# prelec_gamma      1.00882
# sc               11.19498
# tau             0.7265317
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  360.182552  5  80  742.275238     30  32.74458
#
#      p_stay  prelec_gamma         sc       tau
# 0  0.244259       1.00882  11.194976  0.726532
# frey_individual_planned_subj=117(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration            0
# success           True
# nllh          355.7728
# k                    5
# N                   80
# bic           733.4558
# theta               30
# mu            32.73691
# p_stay       0.3531771
# pow_gain     0.2550004
# sc            11.19579
# tau           0.779219
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration            1
# success           True
# nllh          355.7728
# k                    5
# N                   80
# bic           733.4558
# theta               30
# mu            32.73691
# p_stay       0.3531771
# pow_gain     0.2550004
# sc            11.19579
# tau           0.779219
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration            2
# success           True
# nllh          355.7728
# k                    5
# N                   80
# bic           733.4558
# theta               30
# mu            32.73691
# p_stay       0.3531771
# pow_gain     0.2550004
# sc            11.19579
# tau           0.779219
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta         mu  \
# 0          0    True  355.772839  5  80  733.45581     30  32.736906
#
#      p_stay  pow_gain         sc       tau
# 0  0.353177     0.255  11.195789  0.779219
# frey_individual_planned_subj=118(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                 0
# success                True
# nllh               357.7518
# k                         5
# N                        84
# bic                737.6577
# theta                    30
# mu                 20.03671
# p_stay          2.38015e-07
# prelec_gamma       1.586901
# sc                 9.971796
# tau               0.6997057
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                 1
# success                True
# nllh               357.7518
# k                         5
# N                        84
# bic                737.6577
# theta                    30
# mu                 20.03671
# p_stay          2.38015e-07
# prelec_gamma       1.586901
# sc                 9.971796
# tau               0.6997057
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                 2
# success                True
# nllh               357.7518
# k                         5
# N                        84
# bic                737.6577
# theta                    30
# mu                 20.03671
# p_stay          2.38015e-07
# prelec_gamma       1.586901
# sc                 9.971796
# tau               0.6997057
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  357.751822  5  84  737.657727     30  20.03671
#
#          p_stay  prelec_gamma        sc       tau
# 0  2.380150e-07      1.586901  9.971796  0.699706
# frey_individual_planned_subj=118(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             354.2639
# k                       5
# N                      84
# bic              730.6819
# theta                  30
# mu               20.03671
# p_stay       1.439249e-07
# pow_gain        0.3932002
# sc               9.971796
# tau          7.746142e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             354.2639
# k                       5
# N                      84
# bic              730.6819
# theta                  30
# mu               20.03671
# p_stay       1.439249e-07
# pow_gain        0.3932002
# sc               9.971796
# tau          7.746142e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             354.2639
# k                       5
# N                      84
# bic              730.6819
# theta                  30
# mu               20.03671
# p_stay       1.439249e-07
# pow_gain        0.3932002
# sc               9.971796
# tau          7.746142e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  354.263932  5  84  730.681947     30  20.03671
#
#          p_stay  pow_gain        sc           tau
# 0  1.439249e-07    0.3932  9.971796  7.746142e-08
# frey_individual_planned_subj=119(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                343.0252
# k                          5
# N                         83
# bic                 708.1447
# theta                     30
# mu                  18.54441
# p_stay          2.728134e-09
# prelec_gamma        1.937546
# sc                  8.984275
# tau                0.8027014
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                343.0252
# k                          5
# N                         83
# bic                 708.1447
# theta                     30
# mu                  18.54441
# p_stay          2.728134e-09
# prelec_gamma        1.937546
# sc                  8.984275
# tau                0.8027014
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                343.0252
# k                          5
# N                         83
# bic                 708.1447
# theta                     30
# mu                  18.54441
# p_stay          2.728134e-09
# prelec_gamma        1.937546
# sc                  8.984275
# tau                0.8027014
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  343.025247  5  83  708.144697     30  18.544414
#
#          p_stay  prelec_gamma        sc       tau
# 0  2.728134e-09      1.937546  8.984275  0.802701
# frey_individual_planned_subj=119(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             339.9405
# k                       5
# N                      83
# bic              701.9752
# theta                  30
# mu               18.48378
# p_stay       7.251277e-09
# pow_gain        0.3791415
# sc                8.99468
# tau          1.238444e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             339.9405
# k                       5
# N                      83
# bic              701.9752
# theta                  30
# mu               18.48378
# p_stay       7.251277e-09
# pow_gain        0.3791415
# sc                8.99468
# tau          1.238444e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             339.9405
# k                       5
# N                      83
# bic              701.9752
# theta                  30
# mu               18.48378
# p_stay       7.251277e-09
# pow_gain        0.3791415
# sc                8.99468
# tau          1.238444e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  339.940494  5  83  701.975192     30  18.483775
#
#          p_stay  pow_gain       sc           tau
# 0  7.251277e-09  0.379142  8.99468  1.238444e-07
# frey_individual_planned_subj=120(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             348.2345
# k                       5
# N                      84
# bic              718.6231
# theta                  30
# mu                15.4339
# p_stay          0.4636706
# prelec_gamma     1.671423
# sc               9.039846
# tau              0.497447
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             348.2345
# k                       5
# N                      84
# bic              718.6231
# theta                  30
# mu                15.4339
# p_stay          0.4636706
# prelec_gamma     1.671423
# sc               9.039846
# tau              0.497447
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             348.2345
# k                       5
# N                      84
# bic              718.6231
# theta                  30
# mu                15.4339
# p_stay          0.4636706
# prelec_gamma     1.671423
# sc               9.039846
# tau              0.497447
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta         mu  \
# 0          0    True  348.23449  5  84  718.623063     30  15.433897
#
#      p_stay  prelec_gamma        sc       tau
# 0  0.463671      1.671423  9.039846  0.497447
# frey_individual_planned_subj=120(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             349.6638
# k                       5
# N                      84
# bic              721.4816
# theta                  30
# mu               15.37352
# p_stay          0.3760432
# pow_gain        0.6481661
# sc               9.063079
# tau          4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             349.6638
# k                       5
# N                      84
# bic              721.4816
# theta                  30
# mu               15.37352
# p_stay          0.3760432
# pow_gain        0.6481661
# sc               9.063079
# tau          4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             349.6638
# k                       5
# N                      84
# bic              721.4816
# theta                  30
# mu               15.37352
# p_stay          0.3760432
# pow_gain        0.6481661
# sc               9.063079
# tau          4.842124e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  349.663772  5  84  721.481629     30  15.373518
#
#      p_stay  pow_gain        sc       tau
# 0  0.376043  0.648166  9.063079  0.000005
# frey_individual_planned_subj=121(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                400.6851
# k                          5
# N                         84
# bic                 823.5244
# theta                     30
# mu                  54.64959
# p_stay             0.8827023
# prelec_gamma        3.031315
# sc                  20.46009
# tau             7.802552e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                400.6851
# k                          5
# N                         84
# bic                 823.5244
# theta                     30
# mu                  54.64959
# p_stay             0.8827023
# prelec_gamma        3.031315
# sc                  20.46009
# tau             7.802552e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                400.6851
# k                          5
# N                         84
# bic                 823.5244
# theta                     30
# mu                  54.64959
# p_stay             0.8827023
# prelec_gamma        3.031315
# sc                  20.46009
# tau             7.802552e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  400.685136  5  84  823.524356     30  54.649586
#
#      p_stay  prelec_gamma         sc           tau
# 0  0.882702      3.031315  20.460093  7.802552e-07
# frey_individual_planned_subj=121(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             410.3486
# k                       5
# N                      84
# bic              842.8513
# theta                  30
# mu               54.64959
# p_stay       8.989869e-05
# pow_gain        0.4869403
# sc               20.46009
# tau          5.796515e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             410.3486
# k                       5
# N                      84
# bic              842.8513
# theta                  30
# mu               54.64959
# p_stay       8.989869e-05
# pow_gain        0.4869403
# sc               20.46009
# tau          5.796515e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             410.3486
# k                       5
# N                      84
# bic              842.8513
# theta                  30
# mu               54.64959
# p_stay       8.989869e-05
# pow_gain        0.4869403
# sc               20.46009
# tau          5.796515e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  410.348632  5  84  842.851349     30  54.649586
#
#     p_stay  pow_gain         sc           tau
# 0  0.00009   0.48694  20.460091  5.796515e-07
# frey_individual_planned_subj=122(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh               358.703
# k                        5
# N                       84
# bic                 739.56
# theta                   30
# mu                 18.9492
# p_stay          0.03417818
# prelec_gamma      1.568706
# sc                10.26949
# tau              0.5900969
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh               358.703
# k                        5
# N                       84
# bic                 739.56
# theta                   30
# mu                 18.9492
# p_stay          0.03417818
# prelec_gamma      1.568706
# sc                10.26949
# tau              0.5900969
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh               358.703
# k                        5
# N                       84
# bic                 739.56
# theta                   30
# mu                 18.9492
# p_stay          0.03417818
# prelec_gamma      1.568706
# sc                10.26949
# tau              0.5900969
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta       mu    p_stay  \
# 0          0    True  358.702968  5  84  739.56002     30  18.9492  0.034178
#
#    prelec_gamma         sc       tau
# 0      1.568706  10.269485  0.590097
# frey_individual_planned_subj=122(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration              0
# success             True
# nllh            358.5629
# k                      5
# N                     84
# bic             739.2799
# theta                 30
# mu               18.9492
# p_stay       0.002547088
# pow_gain        0.606816
# sc              10.26949
# tau            0.1435052
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration              1
# success             True
# nllh            358.5629
# k                      5
# N                     84
# bic             739.2799
# theta                 30
# mu               18.9492
# p_stay       0.002547088
# pow_gain        0.606816
# sc              10.26949
# tau            0.1435052
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration              2
# success             True
# nllh            358.5629
# k                      5
# N                     84
# bic             739.2799
# theta                 30
# mu               18.9492
# p_stay       0.002547088
# pow_gain        0.606816
# sc              10.26949
# tau            0.1435052
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta       mu    p_stay  \
# 0          0    True  358.562895  5  84  739.279873     30  18.9492  0.002547
#
#    pow_gain         sc       tau
# 0  0.606816  10.269485  0.143505
# frey_individual_planned_subj=123(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             366.2303
# k                       5
# N                      84
# bic              754.6147
# theta                  30
# mu               31.94949
# p_stay          0.2184165
# prelec_gamma     2.299533
# sc               13.08976
# tau             0.2367663
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             366.2303
# k                       5
# N                      84
# bic              754.6147
# theta                  30
# mu               31.94949
# p_stay          0.2184165
# prelec_gamma     2.299533
# sc               13.08976
# tau             0.2367663
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             366.2303
# k                       5
# N                      84
# bic              754.6147
# theta                  30
# mu               31.94949
# p_stay          0.2184165
# prelec_gamma     2.299533
# sc               13.08976
# tau             0.2367663
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  366.230324  5  84  754.614731     30  31.949494
#
#      p_stay  prelec_gamma         sc       tau
# 0  0.218416      2.299533  13.089756  0.236766
# frey_individual_planned_subj=123(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             374.5537
# k                       5
# N                      84
# bic              771.2616
# theta                  30
# mu                 31.959
# p_stay       2.508338e-05
# pow_gain        0.4804076
# sc                 13.089
# tau          2.151665e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             374.5537
# k                       5
# N                      84
# bic              771.2616
# theta                  30
# mu                 31.959
# p_stay       2.508338e-05
# pow_gain        0.4804076
# sc                 13.089
# tau          2.151665e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             374.5537
# k                       5
# N                      84
# bic              771.2616
# theta                  30
# mu                 31.959
# p_stay       2.508338e-05
# pow_gain        0.4804076
# sc                 13.089
# tau          2.151665e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta         mu  \
# 0          0    True  374.553748  5  84  771.26158     30  31.959001
#
#      p_stay  pow_gain         sc           tau
# 0  0.000025  0.480408  13.088996  2.151665e-07
# frey_individual_planned_subj=124(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              287.3596
# k                        5
# N                       84
# bic               596.8732
# theta                   30
# mu                6.068925
# p_stay           0.9707175
# prelec_gamma             5
# sc                4.707117
# tau             0.00302516
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              287.3596
# k                        5
# N                       84
# bic               596.8732
# theta                   30
# mu                6.068925
# p_stay           0.9707175
# prelec_gamma             5
# sc                4.707117
# tau             0.00302516
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              287.3596
# k                        5
# N                       84
# bic               596.8732
# theta                   30
# mu                6.068925
# p_stay           0.9707175
# prelec_gamma             5
# sc                4.707117
# tau             0.00302516
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  287.359561  5  84  596.873205     30  6.068925
#
#      p_stay  prelec_gamma        sc       tau
# 0  0.970718             5  4.707117  0.003025
# frey_individual_planned_subj=124(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           284.4792
# k                     5
# N                    84
# bic            591.1125
# theta                30
# mu             6.063963
# p_stay       0.05435301
# pow_gain      0.3039048
# sc             4.709316
# tau          0.01782941
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           284.4792
# k                     5
# N                    84
# bic            591.1125
# theta                30
# mu             6.063963
# p_stay       0.05435301
# pow_gain      0.3039048
# sc             4.709316
# tau          0.01782941
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           284.4792
# k                     5
# N                    84
# bic            591.1125
# theta                30
# mu             6.063963
# p_stay       0.05435301
# pow_gain      0.3039048
# sc             4.709316
# tau          0.01782941
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  284.479189  5  84  591.112462     30  6.063963
#
#      p_stay  pow_gain        sc       tau
# 0  0.054353  0.303905  4.709316  0.017829
# frey_individual_planned_subj=125(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                407.5253
# k                          5
# N                         84
# bic                 837.2046
# theta                     30
# mu              0.0003738044
# p_stay          1.455553e-08
# prelec_gamma        1.243994
# sc                  32.25151
# tau             3.466433e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                407.5253
# k                          5
# N                         84
# bic                 837.2046
# theta                     30
# mu              0.0003738044
# p_stay          1.455553e-08
# prelec_gamma        1.243994
# sc                  32.25151
# tau             3.466433e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                407.5253
# k                          5
# N                         84
# bic                 837.2046
# theta                     30
# mu              0.0003738044
# p_stay          1.455553e-08
# prelec_gamma        1.243994
# sc                  32.25151
# tau             3.466433e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  407.525251  5  84  837.204585     30  0.000374
#
#          p_stay  prelec_gamma         sc           tau
# 0  1.455553e-08      1.243994  32.251506  3.466433e-08
# frey_individual_planned_subj=125(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             408.4799
# k                       5
# N                      84
# bic              839.1138
# theta                  30
# mu           0.0003738046
# p_stay       5.643049e-09
# pow_gain        0.9219412
# sc               32.25156
# tau          3.508285e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             408.4799
# k                       5
# N                      84
# bic              839.1138
# theta                  30
# mu           0.0003738046
# p_stay       5.643049e-09
# pow_gain        0.9219412
# sc               32.25156
# tau          3.508285e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             408.4799
# k                       5
# N                      84
# bic              839.1138
# theta                  30
# mu           0.0003738046
# p_stay       5.643049e-09
# pow_gain        0.9219412
# sc               32.25156
# tau          3.508285e-07
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta        mu  \
# 0          0    True  408.47987  5  84  839.113824     30  0.000374
#
#          p_stay  pow_gain         sc           tau
# 0  5.643049e-09  0.921941  32.251561  3.508285e-07
# frey_individual_planned_subj=126(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                402.9672
# k                          5
# N                         84
# bic                 828.0884
# theta                     30
# mu                  29.05936
# p_stay          1.486884e-07
# prelec_gamma        1.319651
# sc                  18.58715
# tau             3.466433e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                402.9672
# k                          5
# N                         84
# bic                 828.0884
# theta                     30
# mu                  29.05936
# p_stay          1.486884e-07
# prelec_gamma        1.319651
# sc                  18.58715
# tau             3.466433e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                402.9672
# k                          5
# N                         84
# bic                 828.0884
# theta                     30
# mu                  29.05936
# p_stay          1.486884e-07
# prelec_gamma        1.319651
# sc                  18.58715
# tau             3.466433e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  402.967156  5  84  828.088397     30  29.059361
#
#          p_stay  prelec_gamma         sc           tau
# 0  1.486884e-07      1.319651  18.587147  3.466433e-08
# frey_individual_planned_subj=126(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             404.7552
# k                       5
# N                      84
# bic              831.6645
# theta                  30
# mu               29.05936
# p_stay       2.372192e-09
# pow_gain        0.8642148
# sc               18.58715
# tau          7.756128e-09
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             404.7552
# k                       5
# N                      84
# bic              831.6645
# theta                  30
# mu               29.05936
# p_stay       2.372192e-09
# pow_gain        0.8642148
# sc               18.58715
# tau          7.756128e-09
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             404.7552
# k                       5
# N                      84
# bic              831.6645
# theta                  30
# mu               29.05936
# p_stay       2.372192e-09
# pow_gain        0.8642148
# sc               18.58715
# tau          7.756128e-09
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  404.755213  5  84  831.664511     30  29.059361
#
#          p_stay  pow_gain         sc           tau
# 0  2.372192e-09  0.864215  18.587147  7.756128e-09
# frey_individual_planned_subj=127(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                433.0386
# k                          5
# N                         84
# bic                 888.2313
# theta                     30
# mu                  51.91151
# p_stay          1.112534e-07
# prelec_gamma       0.9910029
# sc                  23.97959
# tau             3.892311e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                433.0386
# k                          5
# N                         84
# bic                 888.2313
# theta                     30
# mu                  51.91151
# p_stay          1.112534e-07
# prelec_gamma       0.9910029
# sc                  23.97959
# tau             3.892311e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                433.0386
# k                          5
# N                         84
# bic                 888.2313
# theta                     30
# mu                  51.91151
# p_stay          1.112534e-07
# prelec_gamma       0.9910029
# sc                  23.97959
# tau             3.892311e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  433.038595  5  84  888.231273     30  51.911507
#
#          p_stay  prelec_gamma        sc           tau
# 0  1.112534e-07      0.991003  23.97959  3.892311e-07
# frey_individual_planned_subj=127(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             432.1371
# k                       5
# N                      84
# bic              886.4283
# theta                  30
# mu               51.91151
# p_stay       1.112534e-07
# pow_gain        0.8381661
# sc               23.97959
# tau           1.94191e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             432.1371
# k                       5
# N                      84
# bic              886.4283
# theta                  30
# mu               51.91151
# p_stay       1.112534e-07
# pow_gain        0.8381661
# sc               23.97959
# tau           1.94191e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             432.1371
# k                       5
# N                      84
# bic              886.4283
# theta                  30
# mu               51.91151
# p_stay       1.112534e-07
# pow_gain        0.8381661
# sc               23.97959
# tau           1.94191e-07
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta         mu  \
# 0          0    True  432.13712  5  84  886.428324     30  51.911507
#
#          p_stay  pow_gain        sc           tau
# 0  1.112534e-07  0.838166  23.97959  1.941910e-07
# frey_individual_planned_subj=128(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                419.0547
# k                          5
# N                         84
# bic                 860.2635
# theta                     30
# mu                  33.08738
# p_stay          2.967458e-11
# prelec_gamma        1.636141
# sc                  23.97664
# tau                0.8489376
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                419.0547
# k                          5
# N                         84
# bic                 860.2635
# theta                     30
# mu                  33.08738
# p_stay          2.967458e-11
# prelec_gamma        1.636141
# sc                  23.97664
# tau                0.8489376
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                419.0547
# k                          5
# N                         84
# bic                 860.2635
# theta                     30
# mu                  33.08738
# p_stay          2.967458e-11
# prelec_gamma        1.636141
# sc                  23.97664
# tau                0.8489376
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  419.054708  5  84  860.263499     30  33.08738
#
#          p_stay  prelec_gamma         sc       tau
# 0  2.967458e-11      1.636141  23.976644  0.848938
# frey_individual_planned_subj=128(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             418.5414
# k                       5
# N                      84
# bic              859.2369
# theta                  30
# mu               32.14196
# p_stay       1.925725e-08
# pow_gain        0.5794883
# sc               24.40555
# tau          1.112324e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             418.5414
# k                       5
# N                      84
# bic              859.2369
# theta                  30
# mu               32.14196
# p_stay       1.925725e-08
# pow_gain        0.5794883
# sc               24.40555
# tau          1.112324e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             418.5414
# k                       5
# N                      84
# bic              859.2369
# theta                  30
# mu               32.14196
# p_stay       1.925725e-08
# pow_gain        0.5794883
# sc               24.40555
# tau          1.112324e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  418.541397  5  84  859.236879     30  32.141961
#
#          p_stay  pow_gain         sc       tau
# 0  1.925725e-08  0.579488  24.405549  0.000001
# frey_individual_planned_subj=129(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                 0
# success                True
# nllh               342.3215
# k                         5
# N                        84
# bic                706.7972
# theta                    30
# mu                 1.879471
# p_stay            0.8492598
# prelec_gamma       3.815415
# sc                 17.03045
# tau             0.004739559
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                 1
# success                True
# nllh               342.3215
# k                         5
# N                        84
# bic                706.7972
# theta                    30
# mu                 1.879471
# p_stay            0.8492598
# prelec_gamma       3.815415
# sc                 17.03045
# tau             0.004739559
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                 2
# success                True
# nllh               342.3215
# k                         5
# N                        84
# bic                706.7972
# theta                    30
# mu                 1.879471
# p_stay            0.8492598
# prelec_gamma       3.815415
# sc                 17.03045
# tau             0.004739559
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta        mu   p_stay  \
# 0          0    True  342.321538  5  84  706.79716     30  1.879471  0.84926
#
#    prelec_gamma         sc      tau
# 0      3.815415  17.030451  0.00474
# frey_individual_planned_subj=129(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             354.0894
# k                       5
# N                      84
# bic              730.3328
# theta                  30
# mu               1.879471
# p_stay       9.309443e-06
# pow_gain        0.4896405
# sc               17.03045
# tau             0.1496051
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             354.0894
# k                       5
# N                      84
# bic              730.3328
# theta                  30
# mu               1.879471
# p_stay       9.309443e-06
# pow_gain        0.4896405
# sc               17.03045
# tau             0.1496051
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             354.0894
# k                       5
# N                      84
# bic              730.3328
# theta                  30
# mu               1.879471
# p_stay       9.309443e-06
# pow_gain        0.4896405
# sc               17.03045
# tau             0.1496051
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  354.089355  5  84  730.332793     30  1.879471
#
#      p_stay  pow_gain         sc       tau
# 0  0.000009   0.48964  17.030451  0.149605
# frey_individual_planned_subj=130(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                252.9546
# k                          5
# N                         84
# bic                 528.0632
# theta                     30
# mu                  6.335367
# p_stay             0.5423469
# prelec_gamma        1.295434
# sc                  2.525673
# tau             4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                252.9546
# k                          5
# N                         84
# bic                 528.0632
# theta                     30
# mu                  6.335367
# p_stay             0.5423469
# prelec_gamma        1.295434
# sc                  2.525673
# tau             4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                252.9546
# k                          5
# N                         84
# bic                 528.0632
# theta                     30
# mu                  6.335367
# p_stay             0.5423469
# prelec_gamma        1.295434
# sc                  2.525673
# tau             4.842124e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta        mu  \
# 0          0    True  252.954554  5  84  528.063191     30  6.335367
#
#      p_stay  prelec_gamma        sc       tau
# 0  0.542347      1.295434  2.525673  0.000005
# frey_individual_planned_subj=130(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             253.0734
# k                       5
# N                      84
# bic              528.3009
# theta                  30
# mu               6.335367
# p_stay          0.4893389
# pow_gain        0.8248177
# sc               2.525673
# tau          4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             253.0734
# k                       5
# N                      84
# bic              528.3009
# theta                  30
# mu               6.335367
# p_stay          0.4893389
# pow_gain        0.8248177
# sc               2.525673
# tau          4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             253.0734
# k                       5
# N                      84
# bic              528.3009
# theta                  30
# mu               6.335367
# p_stay          0.4893389
# pow_gain        0.8248177
# sc               2.525673
# tau          4.842124e-06
# Name: 2, dtype: object
#    iteration success      nllh  k   N         bic  theta        mu    p_stay  \
# 0          0    True  253.0734  5  84  528.300884     30  6.335367  0.489339
#
#    pow_gain        sc       tau
# 0  0.824818  2.525673  0.000005
# frey_individual_planned_subj=131(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                376.4693
# k                          5
# N                         80
# bic                 774.8487
# theta                     30
# mu                  30.96491
# p_stay          3.015969e-07
# prelec_gamma         1.32227
# sc                  16.28204
# tau              0.004625896
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                376.4693
# k                          5
# N                         80
# bic                 774.8487
# theta                     30
# mu                  30.96491
# p_stay          3.015969e-07
# prelec_gamma         1.32227
# sc                  16.28204
# tau              0.004625896
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                376.4693
# k                          5
# N                         80
# bic                 774.8487
# theta                     30
# mu                  30.96491
# p_stay          3.015969e-07
# prelec_gamma         1.32227
# sc                  16.28204
# tau              0.004625896
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  376.469302  5  80  774.848738     30  30.964911
#
#          p_stay  prelec_gamma         sc       tau
# 0  3.015969e-07       1.32227  16.282036  0.004626
# frey_individual_planned_subj=131(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             377.4749
# k                       5
# N                      80
# bic              776.8599
# theta                  30
# mu               30.96491
# p_stay       2.073537e-07
# pow_gain        0.7810413
# sc               16.28204
# tau          1.124422e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             377.4749
# k                       5
# N                      80
# bic              776.8599
# theta                  30
# mu               30.96491
# p_stay       2.073537e-07
# pow_gain        0.7810413
# sc               16.28204
# tau          1.124422e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             377.4749
# k                       5
# N                      80
# bic              776.8599
# theta                  30
# mu               30.96491
# p_stay       2.073537e-07
# pow_gain        0.7810413
# sc               16.28204
# tau          1.124422e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  377.474898  5  80  776.859928     30  30.964911
#
#          p_stay  pow_gain         sc           tau
# 0  2.073537e-07  0.781041  16.282036  1.124422e-08
# frey_individual_planned_subj=132(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                 0
# success                True
# nllh               373.2405
# k                         5
# N                        84
# bic                768.6351
# theta                    30
# mu                 33.73668
# p_stay          0.006142178
# ...
# N                        84
# bic                768.6351
# theta                    30
# mu                 33.73668
# p_stay          0.006142178
# prelec_gamma       1.645546
# sc                 11.69351
# tau               0.7490316
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  373.240507  5  84  768.635097     30  33.736682
#
#      p_stay  prelec_gamma         sc       tau
# 0  0.006142      1.645546  11.693514  0.749032
# frey_individual_planned_subj=132(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             368.6851
# k                       5
# N                      84
# bic              759.5243
# theta                  30
# mu               33.73668
# p_stay       1.972529e-09
# pow_gain        0.4632169
# sc               11.69351
# tau           2.15688e-09
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             368.6851
# k                       5
# N                      84
# bic              759.5243
# theta                  30
# mu               33.73668
# p_stay       1.972529e-09
# pow_gain        0.4632169
# sc               11.69351
# tau           2.15688e-09
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             368.6851
# k                       5
# N                      84
# bic              759.5243
# theta                  30
# mu               33.73668
# p_stay       1.972529e-09
# pow_gain        0.4632169
# sc               11.69351
# tau           2.15688e-09
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  368.685093  5  84  759.524269     30  33.736682
#
#          p_stay  pow_gain         sc           tau
# 0  1.972529e-09  0.463217  11.693514  2.156880e-09
# frey_individual_planned_subj=133(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                318.2083
# k                          5
# N                         75
# bic                  658.004
# theta                     30
# mu                  15.71643
# p_stay             0.7869302
# prelec_gamma       0.1400968
# sc                  10.01976
# tau             2.486135e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                318.2083
# k                          5
# N                         75
# bic                  658.004
# theta                     30
# mu                  15.71643
# p_stay             0.7869302
# prelec_gamma       0.1400968
# sc                  10.01976
# tau             2.486135e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                318.2083
# k                          5
# N                         75
# bic                  658.004
# theta                     30
# mu                  15.71643
# p_stay             0.7869302
# prelec_gamma       0.1400968
# sc                  10.01976
# tau             2.486135e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  318.208259  5  75  658.003958     30  15.716435
#
#     p_stay  prelec_gamma         sc           tau
# 0  0.78693      0.140097  10.019764  2.486135e-07
# frey_individual_planned_subj=133(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             318.3132
# k                       5
# N                      75
# bic              658.2139
# theta                  30
# mu               15.71643
# p_stay          0.9161699
# pow_gain         2.978631
# sc               10.01976
# tau          3.466433e-08
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             318.3132
# k                       5
# N                      75
# bic              658.2139
# theta                  30
# mu               15.71643
# p_stay          0.9161699
# pow_gain         2.978631
# sc               10.01976
# tau          3.466433e-08
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             318.3132
# k                       5
# N                      75
# bic              658.2139
# theta                  30
# mu               15.71643
# p_stay          0.9161699
# pow_gain         2.978631
# sc               10.01976
# tau          3.466433e-08
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  318.313205  5  75  658.213851     30  15.716435
#
#     p_stay  pow_gain         sc           tau
# 0  0.91617  2.978631  10.019764  3.466433e-08
# frey_individual_planned_subj=134(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                328.8116
# k                          5
# N                         84
# bic                 679.7774
# theta                     30
# mu                   16.0218
# p_stay          6.225469e-10
# prelec_gamma        1.587039
# sc                  6.707996
# tau                0.6421254
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                328.8116
# k                          5
# N                         84
# bic                 679.7774
# theta                     30
# mu                   16.0218
# p_stay          6.225469e-10
# prelec_gamma        1.587039
# sc                  6.707996
# tau                0.6421254
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                328.8116
# k                          5
# N                         84
# bic                 679.7774
# theta                     30
# mu                   16.0218
# p_stay          6.225469e-10
# prelec_gamma        1.587039
# sc                  6.707996
# tau                0.6421254
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  328.811639  5  84  679.777362     30  16.021801
#
#          p_stay  prelec_gamma        sc       tau
# 0  6.225469e-10      1.587039  6.707996  0.642125
# frey_individual_planned_subj=134(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             327.6239
# k                       5
# N                      84
# bic              677.4019
# theta                  30
# mu                16.0218
# p_stay       1.305572e-06
# pow_gain        0.4950241
# sc               6.707996
# tau          1.213897e-07
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             327.6239
# k                       5
# N                      84
# bic              677.4019
# theta                  30
# mu                16.0218
# p_stay       1.305572e-06
# pow_gain        0.4950241
# sc               6.707996
# tau          1.213897e-07
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             327.6239
# k                       5
# N                      84
# bic              677.4019
# theta                  30
# mu                16.0218
# p_stay       1.305572e-06
# pow_gain        0.4950241
# sc               6.707996
# tau          1.213897e-07
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta         mu  \
# 0          0    True  327.623913  5  84  677.40191     30  16.021801
#
#      p_stay  pow_gain        sc           tau
# 0  0.000001  0.495024  6.707996  1.213897e-07
# frey_individual_planned_subj=135(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                0
# success               True
# nllh              407.7415
# k                        5
# N                       84
# bic                837.637
# theta                   30
# mu                70.86267
# p_stay          0.04007932
# prelec_gamma      1.503748
# sc                18.84098
# tau              0.4257293
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                1
# success               True
# nllh              407.7415
# k                        5
# N                       84
# bic                837.637
# theta                   30
# mu                70.86267
# p_stay          0.04007932
# prelec_gamma      1.503748
# sc                18.84098
# tau              0.4257293
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                2
# success               True
# nllh              407.7415
# k                        5
# N                       84
# bic                837.637
# theta                   30
# mu                70.86267
# p_stay          0.04007932
# prelec_gamma      1.503748
# sc                18.84098
# tau              0.4257293
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  407.741477  5  84  837.637038     30  70.862671
#
#      p_stay  prelec_gamma         sc       tau
# 0  0.040079      1.503748  18.840975  0.425729
# frey_individual_planned_subj=135(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             413.6193
# k                       5
# N                      84
# bic              849.3926
# theta                  30
# mu               70.86267
# p_stay       1.338367e-08
# pow_gain        0.7619125
# sc               18.84098
# tau          1.797237e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             413.6193
# k                       5
# N                      84
# bic              849.3926
# theta                  30
# mu               70.86267
# p_stay       1.338367e-08
# pow_gain        0.7619125
# sc               18.84098
# tau          1.797237e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             413.6193
# k                       5
# N                      84
# bic              849.3926
# theta                  30
# mu               70.86267
# p_stay       1.338367e-08
# pow_gain        0.7619125
# sc               18.84098
# tau          1.797237e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  413.619276  5  84  849.392636     30  70.862671
#
#          p_stay  pow_gain         sc       tau
# 0  1.338367e-08  0.761913  18.840975  0.000002
# frey_individual_planned_subj=136(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                 354.139
# k                          5
# N                         80
# bic                 730.1882
# theta                     30
# mu                  25.18098
# p_stay             0.4365652
# prelec_gamma        1.798837
# sc                  12.03238
# tau             2.735656e-05
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                 354.139
# k                          5
# N                         80
# bic                 730.1882
# theta                     30
# mu                  25.18098
# p_stay             0.4365652
# prelec_gamma        1.798837
# sc                  12.03238
# tau             2.735656e-05
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                 354.139
# k                          5
# N                         80
# bic                 730.1882
# theta                     30
# mu                  25.18098
# p_stay             0.4365652
# prelec_gamma        1.798837
# sc                  12.03238
# tau             2.735656e-05
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  354.139041  5  80  730.188216     30  25.180978
#
#      p_stay  prelec_gamma         sc       tau
# 0  0.436565      1.798837  12.032382  0.000027
# frey_individual_planned_subj=136(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration             0
# success            True
# nllh           356.6773
# k                     5
# N                    80
# bic            735.2647
# theta                30
# mu             25.18098
# p_stay       0.03015732
# pow_gain      0.6269872
# sc             12.03238
# tau          0.05541826
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration             1
# success            True
# nllh           356.6773
# k                     5
# N                    80
# bic            735.2647
# theta                30
# mu             25.18098
# p_stay       0.03015732
# pow_gain      0.6269872
# sc             12.03238
# tau          0.05541826
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration             2
# success            True
# nllh           356.6773
# k                     5
# N                    80
# bic            735.2647
# theta                30
# mu             25.18098
# p_stay       0.03015732
# pow_gain      0.6269872
# sc             12.03238
# tau          0.05541826
# Name: 2, dtype: object
#    iteration success       nllh  k   N         bic  theta         mu  \
# 0          0    True  356.67728  5  80  735.264693     30  25.180978
#
#      p_stay  pow_gain         sc       tau
# 0  0.030157  0.626987  12.032382  0.055418
# frey_individual_planned_subj=137(mu,p_stay,prelec_gamma,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration                  0
# success                 True
# nllh                  323.17
# k                          5
# N                         84
# bic                 668.4942
# theta                     30
# mu                  15.27259
# p_stay          8.370804e-06
# prelec_gamma        1.588552
# sc                  6.164782
# tau                0.6995883
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration                  1
# success                 True
# nllh                  323.17
# k                          5
# N                         84
# bic                 668.4942
# theta                     30
# mu                  15.27259
# p_stay          8.370804e-06
# prelec_gamma        1.588552
# sc                  6.164782
# tau                0.6995883
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration                  2
# success                 True
# nllh                  323.17
# k                          5
# N                         84
# bic                 668.4942
# theta                     30
# mu                  15.27259
# p_stay          8.370804e-06
# prelec_gamma        1.588552
# sc                  6.164782
# tau                0.6995883
# Name: 2, dtype: object
#    iteration success        nllh  k   N        bic  theta         mu  \
# 0          0    True  323.170033  5  84  668.49415     30  15.272586
#
#      p_stay  prelec_gamma        sc       tau
# 0  0.000008      1.588552  6.164782  0.699588
# frey_individual_planned_subj=137(mu,p_stay,pow_gain,sc,tau|c=0.5,theta=30)
# 0/3
# theta: 30.0
# iteration               0
# success              True
# nllh             322.3281
# k                       5
# N                      84
# bic              666.8103
# theta                  30
# mu               15.27259
# p_stay       5.201945e-05
# pow_gain        0.5464106
# sc               6.164782
# tau          4.842124e-06
# Name: 0, dtype: object
# 1/3
# theta: 30.0
# iteration               1
# success              True
# nllh             322.3281
# k                       5
# N                      84
# bic              666.8103
# theta                  30
# mu               15.27259
# p_stay       5.201945e-05
# pow_gain        0.5464106
# sc               6.164782
# tau          4.842124e-06
# Name: 1, dtype: object
# 2/3
# theta: 30.0
# iteration               2
# success              True
# nllh             322.3281
# k                       5
# N                      84
# bic              666.8103
# theta                  30
# mu               15.27259
# p_stay       5.201945e-05
# pow_gain        0.5464106
# sc               6.164782
# tau          4.842124e-06
# Name: 2, dtype: object
#    iteration success        nllh  k   N         bic  theta         mu  \
# 0          0    True  322.328121  5  84  666.810325     30  15.272586
#
#      p_stay  pow_gain        sc       tau
# 0  0.000052  0.546411  6.164782  0.000005

# %%
sid = 110

# %%
allresults = pd.DataFrame([], columns=['sim_id', 'k', 'N', 'nllh', 'bic'])

for parset in PARSETS_GEOM:
    fitting = {p: PARS[p] for p in parset}
    b = best_result('frey_individual_planned_geom_subj=%s' % sid, FIXED, fitting, outdir=OUTDIR, nopars=True)
    if b is None:
        print 'No success'
    else:
        allresults.loc[allresults.shape[0]] = b

for parset in PARSETS_NORMAL:
    fitting = {p: PARS[p] for p in parset}
    b = best_result('frey_individual_planned_subj=%s' % sid, FIXED, fitting, outdir=OUTDIR, nopars=True)
    if b is None:
        print 'No success'
    else:
        allresults.loc[allresults.shape[0]] = b

allresults.sort('bic')
# Out:
#                                                                                                 sim_id  \
# 3                                    frey_individual_planned_subj=110(mu,p_stay,sc,tau|c=0.5,theta=30)
# 4      frey_individual_planned_subj=110(mu,p_stay,prelec_elevation,prelec_gamma,sc,tau|c=0.5,theta=30)
# 5                    frey_individual_planned_subj=110(mu,p_stay,pow_gain,sc,tau,w_loss|c=0.5,theta=30)
# 0                              frey_individual_planned_geom_subj=110(p_stay,p_stop,tau|c=0.5,theta=30)
# 1  frey_individual_planned_geom_subj=110(p_stay,p_stop,prelec_elevation,prelec_gamma,tau|c=0.5,thet...
# 2              frey_individual_planned_geom_subj=110(p_stay,p_stop,pow_gain,tau,w_loss|c=0.5,theta=30)
#
#    k   N         nllh          bic
# 3  4  84   233.800803   485.324874
# 4  6  84   230.480376   487.545653
# 5  6  84   231.069884   488.724668
# 0  3  84  1990.051243  3993.394936
# 1  5  84  1986.719423  3995.592931
# 2  5  84  1987.319867  3996.793818
