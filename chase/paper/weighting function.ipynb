# %%
from mypy.viz import tableau20
from chase.cpt import w_prelec
p = np.arange(0, 1.01, .01)
fig, axi = plt.subplots(figsize=(4,4))
axi.plot([0, 1], [0, 1], color='gray', alpha=.3)

delta = 1.98
gamma = .8
axi.plot(p, w_prelec(p, delta, gamma), '-', color=tableau20[0], label='HBWE04')

#delta = .2
#gamma = 1.5
#axi.plot(p, w_prelec(p, delta, gamma), '-', color=tableau20[2], label='H-E1')

#delta = .4
#gamma = .8
#axi.plot(p, w_prelec(p, delta, gamma), '-', color=tableau20[4], label='H-E2')



axi.set_title('Probability weighting')
axi.set_xlabel('Objective probability')
axi.set_ylabel('Decision weight')
axi.legend()
axi.set_xlim(0,1)
axi.set_ylim(0,1)
plt.tight_layout()
plt.show()
